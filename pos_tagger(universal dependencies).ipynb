# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## install and load dataset
# !pip install conllu
# Out:
# Collecting conllu
#   Downloading https://files.pythonhosted.org/packages/e4/81/6a0166de55990d32ac4dd8375c83d918486ea2a3ef9036f39620f5bf7f94/conllu-4.3-py2.py3-none-any.whl
# Installing collected packages: conllu
# Successfully installed conllu-4.3

# %%
cd "/content/drive/MyDrive/POS_tagging"
# Out:
# /content/drive/MyDrive/POS_tagging

# %%
# !wget https://lindat.mff.cuni.cz/repository/xmlui/bitstream/handle/11234/1-3105/ud-treebanks-v2.5.tgz
# Out:
# --2021-01-26 04:26:18--  https://lindat.mff.cuni.cz/repository/xmlui/bitstream/handle/11234/1-3105/ud-treebanks-v2.5.tgz
# Resolving lindat.mff.cuni.cz (lindat.mff.cuni.cz)... 195.113.20.140
# Connecting to lindat.mff.cuni.cz (lindat.mff.cuni.cz)|195.113.20.140|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 355216681 (339M) [application/x-gzip]
# Saving to: ‘ud-treebanks-v2.5.tgz’
#
# ud-treebanks-v2.5.t 100%[===================>] 338.76M  21.6MB/s    in 18s
#
# 2021-01-26 04:26:37 (18.6 MB/s) - ‘ud-treebanks-v2.5.tgz’ saved [355216681/355216681]

# %%
# !ls
# Out:
# 'pos_tagger(Penn Treebank data).ipynb'	     ud-treebanks-v2.5.tgz
# 'pos_tagger(universal dependencies).ipynb'

# %%
# !tar -zxvf ud-treebanks-v2.5.tgz
# Out:
# ud-treebanks-v2.5/
# ud-treebanks-v2.5/UD_Portuguese-GSD/
# ud-treebanks-v2.5/UD_Portuguese-GSD/pt_gsd-ud-train.txt
# ud-treebanks-v2.5/UD_Portuguese-GSD/pt_gsd-ud-train.conllu
# ud-treebanks-v2.5/UD_Portuguese-GSD/pt_gsd-ud-test.conllu
# ud-treebanks-v2.5/UD_Portuguese-GSD/README.md
# ud-treebanks-v2.5/UD_Portuguese-GSD/stats.xml
# ud-treebanks-v2.5/UD_Portuguese-GSD/LICENSE.txt
# ud-treebanks-v2.5/UD_Portuguese-GSD/pt_gsd-ud-dev.conllu
# ud-treebanks-v2.5/UD_Portuguese-GSD/pt_gsd-ud-test.txt
# ud-treebanks-v2.5/UD_Portuguese-GSD/pt_gsd-ud-dev.txt
# ud-treebanks-v2.5/UD_Portuguese-PUD/
# ud-treebanks-v2.5/UD_Portuguese-PUD/LICENSE.txt
# ud-treebanks-v2.5/UD_Portuguese-PUD/stats.xml
# ud-treebanks-v2.5/UD_Portuguese-PUD/README.md
# ud-treebanks-v2.5/UD_Portuguese-PUD/pt_pud-ud-test.txt
# ud-treebanks-v2.5/UD_Portuguese-PUD/pt_pud-ud-test.conllu
# ud-treebanks-v2.5/UD_Telugu-MTG/
# ud-treebanks-v2.5/UD_Telugu-MTG/te_mtg-ud-train.txt
# ud-treebanks-v2.5/UD_Telugu-MTG/stats.xml
# ud-treebanks-v2.5/UD_Telugu-MTG/te_mtg-ud-dev.txt
# ud-treebanks-v2.5/UD_Telugu-MTG/te_mtg-ud-test.conllu
# ud-treebanks-v2.5/UD_Telugu-MTG/te_mtg-ud-dev.conllu
# ud-treebanks-v2.5/UD_Telugu-MTG/LICENSE.txt
# ud-treebanks-v2.5/UD_Telugu-MTG/te_mtg-ud-train.conllu
# ud-treebanks-v2.5/UD_Telugu-MTG/te_mtg-ud-test.txt
# ud-treebanks-v2.5/UD_Telugu-MTG/README.txt
# ud-treebanks-v2.5/UD_Warlpiri-UFAL/
# ud-treebanks-v2.5/UD_Warlpiri-UFAL/wbp_ufal-ud-test.txt
# ud-treebanks-v2.5/UD_Warlpiri-UFAL/stats.xml
# ud-treebanks-v2.5/UD_Warlpiri-UFAL/README.md
# ud-treebanks-v2.5/UD_Warlpiri-UFAL/LICENSE.txt
# ud-treebanks-v2.5/UD_Warlpiri-UFAL/wbp_ufal-ud-test.conllu
# ud-treebanks-v2.5/UD_Romanian-RRT/
# ud-treebanks-v2.5/UD_Romanian-RRT/ro_rrt-ud-train.conllu
# ud-treebanks-v2.5/UD_Romanian-RRT/ro_rrt-ud-train.txt
# ud-treebanks-v2.5/UD_Romanian-RRT/stats.xml
# ud-treebanks-v2.5/UD_Romanian-RRT/ro_rrt-ud-dev.conllu
# ud-treebanks-v2.5/UD_Romanian-RRT/README.md
# ud-treebanks-v2.5/UD_Romanian-RRT/LICENSE.txt
# ud-treebanks-v2.5/UD_Romanian-RRT/ro_rrt-ud-dev.txt
# ud-treebanks-v2.5/UD_Romanian-RRT/ro_rrt-ud-test.txt
# ud-treebanks-v2.5/UD_Romanian-RRT/ro_rrt-ud-test.conllu
# ud-treebanks-v2.5/UD_English-GUM/
# ud-treebanks-v2.5/UD_English-GUM/en_gum-ud-train.conllu
# ud-treebanks-v2.5/UD_English-GUM/en_gum-ud-test.conllu
# ud-treebanks-v2.5/UD_English-GUM/stats.xml
# ud-treebanks-v2.5/UD_English-GUM/en_gum-ud-test.txt
# ud-treebanks-v2.5/UD_English-GUM/en_gum-ud-dev.conllu
# ud-treebanks-v2.5/UD_English-GUM/README.md
# ud-treebanks-v2.5/UD_English-GUM/LICENSE.txt
# ud-treebanks-v2.5/UD_English-GUM/en_gum-ud-dev.txt
# ud-treebanks-v2.5/UD_English-GUM/en_gum-ud-train.txt
# ud-treebanks-v2.5/UD_Galician-CTG/
# ud-treebanks-v2.5/UD_Galician-CTG/LICENSE.txt
# ud-treebanks-v2.5/UD_Galician-CTG/gl_ctg-ud-dev.txt
# ud-treebanks-v2.5/UD_Galician-CTG/gl_ctg-ud-test.txt
# ud-treebanks-v2.5/UD_Galician-CTG/stats.xml
# ud-treebanks-v2.5/UD_Galician-CTG/README.txt
# ud-treebanks-v2.5/UD_Galician-CTG/gl_ctg-ud-train.txt
# ud-treebanks-v2.5/UD_Galician-CTG/gl_ctg-ud-dev.conllu
# ud-treebanks-v2.5/UD_Galician-CTG/gl_ctg-ud-train.conllu
# ud-treebanks-v2.5/UD_Galician-CTG/gl_ctg-ud-test.conllu
# ud-treebanks-v2.5/UD_Erzya-JR/
# ud-treebanks-v2.5/UD_Erzya-JR/myv_jr-ud-test.txt
# ud-treebanks-v2.5/UD_Erzya-JR/stats.xml
# ud-treebanks-v2.5/UD_Erzya-JR/README.txt
# ud-treebanks-v2.5/UD_Erzya-JR/LICENSE.txt
# ud-treebanks-v2.5/UD_Erzya-JR/myv_jr-ud-test.conllu
# ud-treebanks-v2.5/UD_Afrikaans-AfriBooms/
# ud-treebanks-v2.5/UD_Afrikaans-AfriBooms/stats.xml
# ud-treebanks-v2.5/UD_Afrikaans-AfriBooms/af_afribooms-ud-train.txt
# ud-treebanks-v2.5/UD_Afrikaans-AfriBooms/README.txt
# ud-treebanks-v2.5/UD_Afrikaans-AfriBooms/af_afribooms-ud-test.conllu
# ud-treebanks-v2.5/UD_Afrikaans-AfriBooms/af_afribooms-ud-dev.txt
# ud-treebanks-v2.5/UD_Afrikaans-AfriBooms/af_afribooms-ud-test.txt
# ud-treebanks-v2.5/UD_Afrikaans-AfriBooms/af_afribooms-ud-train.conllu
# ud-treebanks-v2.5/UD_Afrikaans-AfriBooms/af_afribooms-ud-dev.conllu
# ud-treebanks-v2.5/UD_Afrikaans-AfriBooms/LICENSE.txt
# ud-treebanks-v2.5/UD_French-ParTUT/
# ud-treebanks-v2.5/UD_French-ParTUT/fr_partut-ud-dev.txt
# ud-treebanks-v2.5/UD_French-ParTUT/LICENSE.txt
# ud-treebanks-v2.5/UD_French-ParTUT/stats.xml
# ud-treebanks-v2.5/UD_French-ParTUT/fr_partut-ud-train.conllu
# ud-treebanks-v2.5/UD_French-ParTUT/fr_partut-ud-test.conllu
# ud-treebanks-v2.5/UD_French-ParTUT/fr_partut-ud-dev.conllu
# ud-treebanks-v2.5/UD_French-ParTUT/README.md
# ud-treebanks-v2.5/UD_French-ParTUT/fr_partut-ud-train.txt
# ud-treebanks-v2.5/UD_French-ParTUT/fr_partut-ud-test.txt
# ud-treebanks-v2.5/UD_English-ParTUT/
# ud-treebanks-v2.5/UD_English-ParTUT/en_partut-ud-dev.txt
# ud-treebanks-v2.5/UD_English-ParTUT/en_partut-ud-test.txt
# ud-treebanks-v2.5/UD_English-ParTUT/en_partut-ud-test.conllu
# ud-treebanks-v2.5/UD_English-ParTUT/README.md
# ud-treebanks-v2.5/UD_English-ParTUT/en_partut-ud-dev.conllu
# ud-treebanks-v2.5/UD_English-ParTUT/stats.xml
# ud-treebanks-v2.5/UD_English-ParTUT/en_partut-ud-train.txt
# ud-treebanks-v2.5/UD_English-ParTUT/en_partut-ud-train.conllu
# ud-treebanks-v2.5/UD_English-ParTUT/LICENSE.txt
# ud-treebanks-v2.5/UD_Italian-TWITTIRO/
# ud-treebanks-v2.5/UD_Italian-TWITTIRO/stats.xml
# ud-treebanks-v2.5/UD_Italian-TWITTIRO/it_twittiro-ud-test.txt
# ud-treebanks-v2.5/UD_Italian-TWITTIRO/it_twittiro-ud-train.txt
# ud-treebanks-v2.5/UD_Italian-TWITTIRO/it_twittiro-ud-dev.conllu
# ud-treebanks-v2.5/UD_Italian-TWITTIRO/it_twittiro-ud-train.conllu
# ud-treebanks-v2.5/UD_Italian-TWITTIRO/it_twittiro-ud-dev.txt
# ud-treebanks-v2.5/UD_Italian-TWITTIRO/LICENSE.txt
# ud-treebanks-v2.5/UD_Italian-TWITTIRO/README.md
# ud-treebanks-v2.5/UD_Italian-TWITTIRO/it_twittiro-ud-test.conllu
# ud-treebanks-v2.5/UD_Dutch-Alpino/
# ud-treebanks-v2.5/UD_Dutch-Alpino/nl_alpino-ud-dev.conllu
# ud-treebanks-v2.5/UD_Dutch-Alpino/nl_alpino-ud-train.conllu
# ud-treebanks-v2.5/UD_Dutch-Alpino/README.txt
# ud-treebanks-v2.5/UD_Dutch-Alpino/stats.xml
# ud-treebanks-v2.5/UD_Dutch-Alpino/nl_alpino-ud-dev.txt
# ud-treebanks-v2.5/UD_Dutch-Alpino/LICENSE.txt
# ud-treebanks-v2.5/UD_Dutch-Alpino/nl_alpino-ud-test.conllu
# ud-treebanks-v2.5/UD_Dutch-Alpino/nl_alpino-ud-train.txt
# ud-treebanks-v2.5/UD_Dutch-Alpino/nl_alpino-ud-test.txt
# ud-treebanks-v2.5/UD_Czech-FicTree/
# ud-treebanks-v2.5/UD_Czech-FicTree/cs_fictree-ud-train.conllu
# ud-treebanks-v2.5/UD_Czech-FicTree/cs_fictree-ud-test.txt
# ud-treebanks-v2.5/UD_Czech-FicTree/cs_fictree-ud-train.txt
# ud-treebanks-v2.5/UD_Czech-FicTree/README.md
# ud-treebanks-v2.5/UD_Czech-FicTree/cs_fictree-ud-dev.txt
# ud-treebanks-v2.5/UD_Czech-FicTree/cs_fictree-ud-dev.conllu
# ud-treebanks-v2.5/UD_Czech-FicTree/stats.xml
# ud-treebanks-v2.5/UD_Czech-FicTree/cs_fictree-ud-test.conllu
# ud-treebanks-v2.5/UD_Czech-FicTree/LICENSE.txt
# ud-treebanks-v2.5/UD_Polish-PDB/
# ud-treebanks-v2.5/UD_Polish-PDB/pl_pdb-ud-dev.txt
# ud-treebanks-v2.5/UD_Polish-PDB/README.md
# ud-treebanks-v2.5/UD_Polish-PDB/pl_pdb-ud-train.txt
# ud-treebanks-v2.5/UD_Polish-PDB/stats.xml
# ud-treebanks-v2.5/UD_Polish-PDB/LICENSE.txt
# ud-treebanks-v2.5/UD_Polish-PDB/pl_pdb-ud-test.txt
# ud-treebanks-v2.5/UD_Polish-PDB/pl_pdb-ud-dev.conllu
# ud-treebanks-v2.5/UD_Polish-PDB/pl_pdb-ud-train.conllu
# ud-treebanks-v2.5/UD_Polish-PDB/pl_pdb-ud-test.conllu
# ud-treebanks-v2.5/UD_Assyrian-AS/
# ud-treebanks-v2.5/UD_Assyrian-AS/aii_as-ud-test.conllu
# ud-treebanks-v2.5/UD_Assyrian-AS/LICENSE.txt
# ud-treebanks-v2.5/UD_Assyrian-AS/stats.xml
# ud-treebanks-v2.5/UD_Assyrian-AS/aii_as-ud-test.txt
# ud-treebanks-v2.5/UD_Assyrian-AS/README.md
# ud-treebanks-v2.5/UD_Serbian-SET/
# ud-treebanks-v2.5/UD_Serbian-SET/sr_set-ud-dev.txt
# ud-treebanks-v2.5/UD_Serbian-SET/sr_set-ud-train.conllu
# ud-treebanks-v2.5/UD_Serbian-SET/sr_set-ud-train.txt
# ud-treebanks-v2.5/UD_Serbian-SET/README.md
# ud-treebanks-v2.5/UD_Serbian-SET/sr_set-ud-dev.conllu
# ud-treebanks-v2.5/UD_Serbian-SET/sr_set-ud-test.txt
# ud-treebanks-v2.5/UD_Serbian-SET/stats.xml
# ud-treebanks-v2.5/UD_Serbian-SET/LICENSE.txt
# ud-treebanks-v2.5/UD_Serbian-SET/sr_set-ud-test.conllu
# ud-treebanks-v2.5/UD_Chinese-HK/
# ud-treebanks-v2.5/UD_Chinese-HK/zh_hk-ud-test.txt
# ud-treebanks-v2.5/UD_Chinese-HK/README.md
# ud-treebanks-v2.5/UD_Chinese-HK/zh_hk-ud-test.conllu
# ud-treebanks-v2.5/UD_Chinese-HK/stats.xml
# ud-treebanks-v2.5/UD_Chinese-HK/LICENSE.txt
# ud-treebanks-v2.5/UD_Maltese-MUDT/
# ud-treebanks-v2.5/UD_Maltese-MUDT/mt_mudt-ud-dev.txt
# ud-treebanks-v2.5/UD_Maltese-MUDT/mt_mudt-ud-train.conllu
# ud-treebanks-v2.5/UD_Maltese-MUDT/mt_mudt-ud-train.txt
# ud-treebanks-v2.5/UD_Maltese-MUDT/LICENSE.txt
# ud-treebanks-v2.5/UD_Maltese-MUDT/README.md
# ud-treebanks-v2.5/UD_Maltese-MUDT/mt_mudt-ud-test.txt
# ud-treebanks-v2.5/UD_Maltese-MUDT/stats.xml
# ud-treebanks-v2.5/UD_Maltese-MUDT/mt_mudt-ud-dev.conllu
# ud-treebanks-v2.5/UD_Maltese-MUDT/mt_mudt-ud-test.conllu
# ud-treebanks-v2.5/UD_French-Sequoia/
# ud-treebanks-v2.5/UD_French-Sequoia/fr_sequoia-ud-test.txt
# ud-treebanks-v2.5/UD_French-Sequoia/fr_sequoia-ud-dev.conllu
# ud-treebanks-v2.5/UD_French-Sequoia/fr_sequoia-ud-train.txt
# ud-treebanks-v2.5/UD_French-Sequoia/fr_sequoia-ud-train.conllu
# ud-treebanks-v2.5/UD_French-Sequoia/fr_sequoia-ud-dev.txt
# ud-treebanks-v2.5/UD_French-Sequoia/README.md
# ud-treebanks-v2.5/UD_French-Sequoia/stats.xml
# ud-treebanks-v2.5/UD_French-Sequoia/LICENSE.txt
# ud-treebanks-v2.5/UD_French-Sequoia/fr_sequoia-ud-test.conllu
# ud-treebanks-v2.5/UD_English-PUD/
# ud-treebanks-v2.5/UD_English-PUD/en_pud-ud-test.conllu
# ud-treebanks-v2.5/UD_English-PUD/stats.xml
# ud-treebanks-v2.5/UD_English-PUD/LICENSE.txt
# ud-treebanks-v2.5/UD_English-PUD/en_pud-ud-test.txt
# ud-treebanks-v2.5/UD_English-PUD/README.md
# ud-treebanks-v2.5/UD_Irish-IDT/
# ud-treebanks-v2.5/UD_Irish-IDT/ga_idt-ud-dev.conllu
# ud-treebanks-v2.5/UD_Irish-IDT/ga_idt-ud-test.txt
# ud-treebanks-v2.5/UD_Irish-IDT/stats.xml
# ud-treebanks-v2.5/UD_Irish-IDT/ga_idt-ud-train.conllu
# ud-treebanks-v2.5/UD_Irish-IDT/ga_idt-ud-train.txt
# ud-treebanks-v2.5/UD_Irish-IDT/ga_idt-ud-test.conllu
# ud-treebanks-v2.5/UD_Irish-IDT/README.txt
# ud-treebanks-v2.5/UD_Irish-IDT/LICENSE.txt
# ud-treebanks-v2.5/UD_Irish-IDT/ga_idt-ud-dev.txt
# ud-treebanks-v2.5/UD_Estonian-EWT/
# ud-treebanks-v2.5/UD_Estonian-EWT/et_ewt-ud-train.txt
# ud-treebanks-v2.5/UD_Estonian-EWT/README.md
# ud-treebanks-v2.5/UD_Estonian-EWT/et_ewt-ud-train.conllu
# ud-treebanks-v2.5/UD_Estonian-EWT/LICENSE.txt
# ud-treebanks-v2.5/UD_Estonian-EWT/et_ewt-ud-test.conllu
# ud-treebanks-v2.5/UD_Estonian-EWT/et_ewt-ud-test.txt
# ud-treebanks-v2.5/UD_Estonian-EWT/stats.xml
# ud-treebanks-v2.5/UD_Polish-LFG/
# ud-treebanks-v2.5/UD_Polish-LFG/stats.xml
# ud-treebanks-v2.5/UD_Polish-LFG/pl_lfg-ud-test.conllu
# ud-treebanks-v2.5/UD_Polish-LFG/pl_lfg-ud-dev.txt
# ud-treebanks-v2.5/UD_Polish-LFG/pl_lfg-ud-train.conllu
# ud-treebanks-v2.5/UD_Polish-LFG/pl_lfg-ud-dev.conllu
# ud-treebanks-v2.5/UD_Polish-LFG/pl_lfg-ud-train.txt
# ud-treebanks-v2.5/UD_Polish-LFG/LICENSE.txt
# ud-treebanks-v2.5/UD_Polish-LFG/pl_lfg-ud-test.txt
# ud-treebanks-v2.5/UD_Polish-LFG/README.md
# ud-treebanks-v2.5/UD_Czech-CLTT/
# ud-treebanks-v2.5/UD_Czech-CLTT/LICENSE.txt
# ud-treebanks-v2.5/UD_Czech-CLTT/README.md
# ud-treebanks-v2.5/UD_Czech-CLTT/cs_cltt-ud-dev.txt
# ud-treebanks-v2.5/UD_Czech-CLTT/cs_cltt-ud-test.conllu
# ud-treebanks-v2.5/UD_Czech-CLTT/cs_cltt-ud-train.conllu
# ud-treebanks-v2.5/UD_Czech-CLTT/cs_cltt-ud-test.txt
# ud-treebanks-v2.5/UD_Czech-CLTT/cs_cltt-ud-train.txt
# ud-treebanks-v2.5/UD_Czech-CLTT/cs_cltt-ud-dev.conllu
# ud-treebanks-v2.5/UD_Czech-CLTT/stats.xml
# ud-treebanks-v2.5/UD_Naija-NSC/
# ud-treebanks-v2.5/UD_Naija-NSC/pcm_nsc-ud-test.conllu
# ud-treebanks-v2.5/UD_Naija-NSC/README.md
# ud-treebanks-v2.5/UD_Naija-NSC/LICENSE.txt
# ud-treebanks-v2.5/UD_Naija-NSC/stats.xml
# ud-treebanks-v2.5/UD_Naija-NSC/pcm_nsc-ud-test.txt
# ud-treebanks-v2.5/UD_Old_Russian-TOROT/
# ud-treebanks-v2.5/UD_Old_Russian-TOROT/LICENSE.txt
# ud-treebanks-v2.5/UD_Old_Russian-TOROT/orv_torot-ud-train.conllu
# ud-treebanks-v2.5/UD_Old_Russian-TOROT/stats.xml
# ud-treebanks-v2.5/UD_Old_Russian-TOROT/orv_torot-ud-train.txt
# ud-treebanks-v2.5/UD_Old_Russian-TOROT/orv_torot-ud-test.conllu
# ud-treebanks-v2.5/UD_Old_Russian-TOROT/orv_torot-ud-dev.txt
# ud-treebanks-v2.5/UD_Old_Russian-TOROT/orv_torot-ud-dev.conllu
# ud-treebanks-v2.5/UD_Old_Russian-TOROT/README.md
# ud-treebanks-v2.5/UD_Old_Russian-TOROT/orv_torot-ud-test.txt
# ud-treebanks-v2.5/UD_Buryat-BDT/
# ud-treebanks-v2.5/UD_Buryat-BDT/stats.xml
# ud-treebanks-v2.5/UD_Buryat-BDT/bxr_bdt-ud-train.conllu
# ud-treebanks-v2.5/UD_Buryat-BDT/LICENSE.txt
# ud-treebanks-v2.5/UD_Buryat-BDT/bxr_bdt-ud-train.txt
# ud-treebanks-v2.5/UD_Buryat-BDT/bxr_bdt-ud-test.txt
# ud-treebanks-v2.5/UD_Buryat-BDT/README.txt
# ud-treebanks-v2.5/UD_Buryat-BDT/bxr_bdt-ud-test.conllu
# ud-treebanks-v2.5/UD_Hindi-PUD/
# ud-treebanks-v2.5/UD_Hindi-PUD/hi_pud-ud-test.txt
# ud-treebanks-v2.5/UD_Hindi-PUD/stats.xml
# ud-treebanks-v2.5/UD_Hindi-PUD/LICENSE.txt
# ud-treebanks-v2.5/UD_Hindi-PUD/hi_pud-ud-test.conllu
# ud-treebanks-v2.5/UD_Hindi-PUD/README.md
# ud-treebanks-v2.5/UD_French-FQB/
# ud-treebanks-v2.5/UD_French-FQB/LICENSE.txt
# ud-treebanks-v2.5/UD_French-FQB/fr_fqb-ud-test.txt
# ud-treebanks-v2.5/UD_French-FQB/stats.xml
# ud-treebanks-v2.5/UD_French-FQB/fr_fqb-ud-test.conllu
# ud-treebanks-v2.5/UD_French-FQB/README.md
# ud-treebanks-v2.5/UD_Portuguese-Bosque/
# ud-treebanks-v2.5/UD_Portuguese-Bosque/LICENSE.txt
# ud-treebanks-v2.5/UD_Portuguese-Bosque/stats.xml
# ud-treebanks-v2.5/UD_Portuguese-Bosque/pt_bosque-ud-dev.txt
# ud-treebanks-v2.5/UD_Portuguese-Bosque/pt_bosque-ud-dev.conllu
# ud-treebanks-v2.5/UD_Portuguese-Bosque/pt_bosque-ud-train.conllu
# ud-treebanks-v2.5/UD_Portuguese-Bosque/README.md
# ud-treebanks-v2.5/UD_Portuguese-Bosque/pt_bosque-ud-test.conllu
# ud-treebanks-v2.5/UD_Portuguese-Bosque/pt_bosque-ud-test.txt
# ud-treebanks-v2.5/UD_Portuguese-Bosque/pt_bosque-ud-train.txt
# ud-treebanks-v2.5/UD_Russian-GSD/
# ud-treebanks-v2.5/UD_Russian-GSD/ru_gsd-ud-train.conllu
# ud-treebanks-v2.5/UD_Russian-GSD/ru_gsd-ud-test.conllu
# ud-treebanks-v2.5/UD_Russian-GSD/ru_gsd-ud-dev.txt
# ud-treebanks-v2.5/UD_Russian-GSD/README.md
# ud-treebanks-v2.5/UD_Russian-GSD/ru_gsd-ud-dev.conllu
# ud-treebanks-v2.5/UD_Russian-GSD/LICENSE.txt
# ud-treebanks-v2.5/UD_Russian-GSD/ru_gsd-ud-test.txt
# ud-treebanks-v2.5/UD_Russian-GSD/stats.xml
# ud-treebanks-v2.5/UD_Russian-GSD/ru_gsd-ud-train.txt
# ud-treebanks-v2.5/UD_English-Pronouns/
# ud-treebanks-v2.5/UD_English-Pronouns/en_pronouns-ud-test.txt
# ud-treebanks-v2.5/UD_English-Pronouns/README.md
# ud-treebanks-v2.5/UD_English-Pronouns/LICENSE.txt
# ud-treebanks-v2.5/UD_English-Pronouns/stats.xml
# ud-treebanks-v2.5/UD_English-Pronouns/en_pronouns-ud-test.conllu
# ud-treebanks-v2.5/UD_Russian-PUD/
# ud-treebanks-v2.5/UD_Russian-PUD/README.md
# ud-treebanks-v2.5/UD_Russian-PUD/ru_pud-ud-test.conllu
# ud-treebanks-v2.5/UD_Russian-PUD/ru_pud-ud-test.txt
# ud-treebanks-v2.5/UD_Russian-PUD/LICENSE.txt
# ud-treebanks-v2.5/UD_Russian-PUD/stats.xml
# ud-treebanks-v2.5/UD_Russian-SynTagRus/
# ud-treebanks-v2.5/UD_Russian-SynTagRus/ru_syntagrus-ud-test.conllu
# ud-treebanks-v2.5/UD_Russian-SynTagRus/ru_syntagrus-ud-dev.conllu
# ud-treebanks-v2.5/UD_Russian-SynTagRus/LICENSE.txt
# ud-treebanks-v2.5/UD_Russian-SynTagRus/ru_syntagrus-ud-train.conllu
# ud-treebanks-v2.5/UD_Russian-SynTagRus/stats.xml
# ud-treebanks-v2.5/UD_Russian-SynTagRus/ru_syntagrus-ud-dev.txt
# ud-treebanks-v2.5/UD_Russian-SynTagRus/ru_syntagrus-ud-train.txt
# ud-treebanks-v2.5/UD_Russian-SynTagRus/README.txt
# ud-treebanks-v2.5/UD_Russian-SynTagRus/ru_syntagrus-ud-test.txt
# ud-treebanks-v2.5/UD_German-PUD/
# ud-treebanks-v2.5/UD_German-PUD/stats.xml
# ud-treebanks-v2.5/UD_German-PUD/de_pud-ud-test.txt
# ud-treebanks-v2.5/UD_German-PUD/de_pud-ud-test.conllu
# ud-treebanks-v2.5/UD_German-PUD/README.md
# ud-treebanks-v2.5/UD_German-PUD/LICENSE.txt
# ud-treebanks-v2.5/UD_German-GSD/
# ud-treebanks-v2.5/UD_German-GSD/de_gsd-ud-test.conllu
# ud-treebanks-v2.5/UD_German-GSD/stats.xml
# ud-treebanks-v2.5/UD_German-GSD/de_gsd-ud-test.txt
# ud-treebanks-v2.5/UD_German-GSD/de_gsd-ud-dev.conllu
# ud-treebanks-v2.5/UD_German-GSD/de_gsd-ud-dev.txt
# ud-treebanks-v2.5/UD_German-GSD/LICENSE.txt
# ud-treebanks-v2.5/UD_German-GSD/de_gsd-ud-train.txt
# ud-treebanks-v2.5/UD_German-GSD/README.md
# ud-treebanks-v2.5/UD_German-GSD/de_gsd-ud-train.conllu
# ud-treebanks-v2.5/UD_Skolt_Sami-Giellagas/
# ud-treebanks-v2.5/UD_Skolt_Sami-Giellagas/sms_giellagas-ud-test.txt
# ud-treebanks-v2.5/UD_Skolt_Sami-Giellagas/README.md
# ud-treebanks-v2.5/UD_Skolt_Sami-Giellagas/LICENSE.txt
# ud-treebanks-v2.5/UD_Skolt_Sami-Giellagas/sms_giellagas-ud-test.conllu
# ud-treebanks-v2.5/UD_Skolt_Sami-Giellagas/stats.xml
# ud-treebanks-v2.5/UD_Marathi-UFAL/
# ud-treebanks-v2.5/UD_Marathi-UFAL/mr_ufal-ud-test.conllu
# ud-treebanks-v2.5/UD_Marathi-UFAL/mr_ufal-ud-test.txt
# ud-treebanks-v2.5/UD_Marathi-UFAL/mr_ufal-ud-dev.txt
# ud-treebanks-v2.5/UD_Marathi-UFAL/mr_ufal-ud-dev.conllu
# ud-treebanks-v2.5/UD_Marathi-UFAL/mr_ufal-ud-train.conllu
# ud-treebanks-v2.5/UD_Marathi-UFAL/mr_ufal-ud-train.txt
# ud-treebanks-v2.5/UD_Marathi-UFAL/README.txt
# ud-treebanks-v2.5/UD_Marathi-UFAL/stats.xml
# ud-treebanks-v2.5/UD_Marathi-UFAL/LICENSE.txt
# ud-treebanks-v2.5/UD_Finnish-PUD/
# ud-treebanks-v2.5/UD_Finnish-PUD/LICENSE.txt
# ud-treebanks-v2.5/UD_Finnish-PUD/stats.xml
# ud-treebanks-v2.5/UD_Finnish-PUD/README.txt
# ud-treebanks-v2.5/UD_Finnish-PUD/fi_pud-ud-test.conllu
# ud-treebanks-v2.5/UD_Finnish-PUD/fi_pud-ud-test.txt
# ud-treebanks-v2.5/UD_Welsh-CCG/
# ud-treebanks-v2.5/UD_Welsh-CCG/LICENSE.txt
# ud-treebanks-v2.5/UD_Welsh-CCG/stats.xml
# ud-treebanks-v2.5/UD_Welsh-CCG/cy_ccg-ud-test.txt
# ud-treebanks-v2.5/UD_Welsh-CCG/README.md
# ud-treebanks-v2.5/UD_Welsh-CCG/cy_ccg-ud-test.conllu
# ud-treebanks-v2.5/UD_French-Spoken/
# ud-treebanks-v2.5/UD_French-Spoken/fr_spoken-ud-test.txt
# ud-treebanks-v2.5/UD_French-Spoken/README.md
# ud-treebanks-v2.5/UD_French-Spoken/LICENSE.txt
# ud-treebanks-v2.5/UD_French-Spoken/fr_spoken-ud-dev.txt
# ud-treebanks-v2.5/UD_French-Spoken/fr_spoken-ud-dev.conllu
# ud-treebanks-v2.5/UD_French-Spoken/fr_spoken-ud-test.conllu
# ud-treebanks-v2.5/UD_French-Spoken/fr_spoken-ud-train.txt
# ud-treebanks-v2.5/UD_French-Spoken/fr_spoken-ud-train.conllu
# ud-treebanks-v2.5/UD_French-Spoken/stats.xml
# ud-treebanks-v2.5/UD_Slovenian-SST/
# ud-treebanks-v2.5/UD_Slovenian-SST/stats.xml
# ud-treebanks-v2.5/UD_Slovenian-SST/README.txt
# ud-treebanks-v2.5/UD_Slovenian-SST/sl_sst-ud-train.conllu
# ud-treebanks-v2.5/UD_Slovenian-SST/sl_sst-ud-test.conllu
# ud-treebanks-v2.5/UD_Slovenian-SST/sl_sst-ud-test.txt
# ud-treebanks-v2.5/UD_Slovenian-SST/LICENSE.txt
# ud-treebanks-v2.5/UD_Slovenian-SST/sl_sst-ud-train.txt
# ud-treebanks-v2.5/UD_French-PUD/
# ud-treebanks-v2.5/UD_French-PUD/fr_pud-ud-test.txt
# ud-treebanks-v2.5/UD_French-PUD/stats.xml
# ud-treebanks-v2.5/UD_French-PUD/README.md
# ud-treebanks-v2.5/UD_French-PUD/LICENSE.txt
# ud-treebanks-v2.5/UD_French-PUD/fr_pud-ud-test.conllu
# ud-treebanks-v2.5/UD_Japanese-Modern/
# ud-treebanks-v2.5/UD_Japanese-Modern/stats.xml
# ud-treebanks-v2.5/UD_Japanese-Modern/README.txt
# ud-treebanks-v2.5/UD_Japanese-Modern/ja_modern-ud-test.conllu
# ud-treebanks-v2.5/UD_Japanese-Modern/ja_modern-ud-test.txt
# ud-treebanks-v2.5/UD_Japanese-Modern/LICENSE.txt
# ud-treebanks-v2.5/UD_Slovenian-SSJ/
# ud-treebanks-v2.5/UD_Slovenian-SSJ/sl_ssj-ud-dev.conllu
# ud-treebanks-v2.5/UD_Slovenian-SSJ/stats.xml
# ud-treebanks-v2.5/UD_Slovenian-SSJ/sl_ssj-ud-test.txt
# ud-treebanks-v2.5/UD_Slovenian-SSJ/sl_ssj-ud-train.conllu
# ud-treebanks-v2.5/UD_Slovenian-SSJ/README.txt
# ud-treebanks-v2.5/UD_Slovenian-SSJ/sl_ssj-ud-test.conllu
# ud-treebanks-v2.5/UD_Slovenian-SSJ/LICENSE.txt
# ud-treebanks-v2.5/UD_Slovenian-SSJ/sl_ssj-ud-train.txt
# ud-treebanks-v2.5/UD_Slovenian-SSJ/sl_ssj-ud-dev.txt
# ud-treebanks-v2.5/UD_French-GSD/
# ud-treebanks-v2.5/UD_French-GSD/fr_gsd-ud-dev.txt
# ud-treebanks-v2.5/UD_French-GSD/fr_gsd-ud-test.txt
# ud-treebanks-v2.5/UD_French-GSD/fr_gsd-ud-train.conllu
# ud-treebanks-v2.5/UD_French-GSD/README.md
# ud-treebanks-v2.5/UD_French-GSD/LICENSE.txt
# ud-treebanks-v2.5/UD_French-GSD/fr_gsd-ud-train.txt
# ud-treebanks-v2.5/UD_French-GSD/stats.xml
# ud-treebanks-v2.5/UD_French-GSD/fr_gsd-ud-dev.conllu
# ud-treebanks-v2.5/UD_French-GSD/fr_gsd-ud-test.conllu
# ud-treebanks-v2.5/UD_Arabic-PADT/
# ud-treebanks-v2.5/UD_Arabic-PADT/ar_padt-ud-train.conllu
# ud-treebanks-v2.5/UD_Arabic-PADT/ar_padt-ud-test.txt
# ud-treebanks-v2.5/UD_Arabic-PADT/ar_padt-ud-test.conllu
# ud-treebanks-v2.5/UD_Arabic-PADT/ar_padt-ud-dev.conllu
# ud-treebanks-v2.5/UD_Arabic-PADT/LICENSE.txt
# ud-treebanks-v2.5/UD_Arabic-PADT/ar_padt-ud-dev.txt
# ud-treebanks-v2.5/UD_Arabic-PADT/ar_padt-ud-train.txt
# ud-treebanks-v2.5/UD_Arabic-PADT/stats.xml
# ud-treebanks-v2.5/UD_Arabic-PADT/README.md
# ud-treebanks-v2.5/UD_Chinese-GSD/
# ud-treebanks-v2.5/UD_Chinese-GSD/stats.xml
# ud-treebanks-v2.5/UD_Chinese-GSD/LICENSE.txt
# ud-treebanks-v2.5/UD_Chinese-GSD/zh_gsd-ud-dev.txt
# ud-treebanks-v2.5/UD_Chinese-GSD/zh_gsd-ud-train.conllu
# ud-treebanks-v2.5/UD_Chinese-GSD/zh_gsd-ud-dev.conllu
# ud-treebanks-v2.5/UD_Chinese-GSD/zh_gsd-ud-test.conllu
# ud-treebanks-v2.5/UD_Chinese-GSD/README.md
# ud-treebanks-v2.5/UD_Chinese-GSD/zh_gsd-ud-test.txt
# ud-treebanks-v2.5/UD_Chinese-GSD/zh_gsd-ud-train.txt
# ud-treebanks-v2.5/UD_Chinese-PUD/
# ud-treebanks-v2.5/UD_Chinese-PUD/LICENSE.txt
# ud-treebanks-v2.5/UD_Chinese-PUD/stats.xml
# ud-treebanks-v2.5/UD_Chinese-PUD/zh_pud-ud-test.conllu
# ud-treebanks-v2.5/UD_Chinese-PUD/zh_pud-ud-test.txt
# ud-treebanks-v2.5/UD_Chinese-PUD/README.md
# ud-treebanks-v2.5/UD_Latin-ITTB/
# ud-treebanks-v2.5/UD_Latin-ITTB/README.md
# ud-treebanks-v2.5/UD_Latin-ITTB/la_ittb-ud-test.conllu
# ud-treebanks-v2.5/UD_Latin-ITTB/la_ittb-ud-train.conllu
# ud-treebanks-v2.5/UD_Latin-ITTB/la_ittb-ud-train.txt
# ud-treebanks-v2.5/UD_Latin-ITTB/la_ittb-ud-test.txt
# ud-treebanks-v2.5/UD_Latin-ITTB/la_ittb-ud-dev.conllu
# ud-treebanks-v2.5/UD_Latin-ITTB/stats.xml
# ud-treebanks-v2.5/UD_Latin-ITTB/LICENSE.txt
# ud-treebanks-v2.5/UD_Latin-ITTB/la_ittb-ud-dev.txt
# ud-treebanks-v2.5/UD_Catalan-AnCora/
# ud-treebanks-v2.5/UD_Catalan-AnCora/ca_ancora-ud-dev.conllu
# ud-treebanks-v2.5/UD_Catalan-AnCora/README.md
# ud-treebanks-v2.5/UD_Catalan-AnCora/ca_ancora-ud-train.txt
# ud-treebanks-v2.5/UD_Catalan-AnCora/ca_ancora-ud-dev.txt
# ud-treebanks-v2.5/UD_Catalan-AnCora/ca_ancora-ud-test.txt
# ud-treebanks-v2.5/UD_Catalan-AnCora/ca_ancora-ud-test.conllu
# ud-treebanks-v2.5/UD_Catalan-AnCora/stats.xml
# ud-treebanks-v2.5/UD_Catalan-AnCora/LICENSE.txt
# ud-treebanks-v2.5/UD_Catalan-AnCora/ca_ancora-ud-train.conllu
# ud-treebanks-v2.5/UD_Spanish-PUD/
# ud-treebanks-v2.5/UD_Spanish-PUD/es_pud-ud-test.txt
# ud-treebanks-v2.5/UD_Spanish-PUD/stats.xml
# ud-treebanks-v2.5/UD_Spanish-PUD/LICENSE.txt
# ud-treebanks-v2.5/UD_Spanish-PUD/README.md
# ud-treebanks-v2.5/UD_Spanish-PUD/es_pud-ud-test.conllu
# ud-treebanks-v2.5/UD_Spanish-GSD/
# ud-treebanks-v2.5/UD_Spanish-GSD/es_gsd-ud-dev.conllu
# ud-treebanks-v2.5/UD_Spanish-GSD/es_gsd-ud-train.conllu
# ud-treebanks-v2.5/UD_Spanish-GSD/stats.xml
# ud-treebanks-v2.5/UD_Spanish-GSD/es_gsd-ud-train.txt
# ud-treebanks-v2.5/UD_Spanish-GSD/es_gsd-ud-test.conllu
# ud-treebanks-v2.5/UD_Spanish-GSD/es_gsd-ud-test.txt
# ud-treebanks-v2.5/UD_Spanish-GSD/README.md
# ud-treebanks-v2.5/UD_Spanish-GSD/es_gsd-ud-dev.txt
# ud-treebanks-v2.5/UD_Spanish-GSD/LICENSE.txt
# ud-treebanks-v2.5/UD_Italian-ParTUT/
# ud-treebanks-v2.5/UD_Italian-ParTUT/stats.xml
# ud-treebanks-v2.5/UD_Italian-ParTUT/LICENSE.txt
# ud-treebanks-v2.5/UD_Italian-ParTUT/it_partut-ud-train.txt
# ud-treebanks-v2.5/UD_Italian-ParTUT/it_partut-ud-test.txt
# ud-treebanks-v2.5/UD_Italian-ParTUT/it_partut-ud-dev.txt
# ud-treebanks-v2.5/UD_Italian-ParTUT/it_partut-ud-dev.conllu
# ud-treebanks-v2.5/UD_Italian-ParTUT/it_partut-ud-test.conllu
# ud-treebanks-v2.5/UD_Italian-ParTUT/README.md
# ud-treebanks-v2.5/UD_Italian-ParTUT/it_partut-ud-train.conllu
# ud-treebanks-v2.5/UD_Italian-PoSTWITA/
# ud-treebanks-v2.5/UD_Italian-PoSTWITA/README.md
# ud-treebanks-v2.5/UD_Italian-PoSTWITA/it_postwita-ud-train.conllu
# ud-treebanks-v2.5/UD_Italian-PoSTWITA/it_postwita-ud-dev.conllu
# ud-treebanks-v2.5/UD_Italian-PoSTWITA/it_postwita-ud-test.conllu
# ud-treebanks-v2.5/UD_Italian-PoSTWITA/stats.xml
# ud-treebanks-v2.5/UD_Italian-PoSTWITA/LICENSE.txt
# ud-treebanks-v2.5/UD_Italian-PoSTWITA/it_postwita-ud-dev.txt
# ud-treebanks-v2.5/UD_Italian-PoSTWITA/it_postwita-ud-test.txt
# ud-treebanks-v2.5/UD_Italian-PoSTWITA/it_postwita-ud-train.txt
# ud-treebanks-v2.5/UD_Old_Russian-RNC/
# ud-treebanks-v2.5/UD_Old_Russian-RNC/README.md
# ud-treebanks-v2.5/UD_Old_Russian-RNC/LICENSE.txt
# ud-treebanks-v2.5/UD_Old_Russian-RNC/orv_rnc-ud-test.conllu
# ud-treebanks-v2.5/UD_Old_Russian-RNC/stats.xml
# ud-treebanks-v2.5/UD_Old_Russian-RNC/orv_rnc-ud-test.txt
# ud-treebanks-v2.5/UD_Mbya_Guarani-Thomas/
# ud-treebanks-v2.5/UD_Mbya_Guarani-Thomas/README.md
# ud-treebanks-v2.5/UD_Mbya_Guarani-Thomas/stats.xml
# ud-treebanks-v2.5/UD_Mbya_Guarani-Thomas/gun_thomas-ud-test.conllu
# ud-treebanks-v2.5/UD_Mbya_Guarani-Thomas/gun_thomas-ud-test.txt
# ud-treebanks-v2.5/UD_Mbya_Guarani-Thomas/LICENSE.txt
# ud-treebanks-v2.5/UD_Galician-TreeGal/
# ud-treebanks-v2.5/UD_Galician-TreeGal/gl_treegal-ud-train.conllu
# ud-treebanks-v2.5/UD_Galician-TreeGal/README.md
# ud-treebanks-v2.5/UD_Galician-TreeGal/gl_treegal-ud-test.txt
# ud-treebanks-v2.5/UD_Galician-TreeGal/gl_treegal-ud-train.txt
# ud-treebanks-v2.5/UD_Galician-TreeGal/gl_treegal-ud-test.conllu
# ud-treebanks-v2.5/UD_Galician-TreeGal/stats.xml
# ud-treebanks-v2.5/UD_Galician-TreeGal/LICENSE.txt
# ud-treebanks-v2.5/UD_Arabic-PUD/
# ud-treebanks-v2.5/UD_Arabic-PUD/README.md
# ud-treebanks-v2.5/UD_Arabic-PUD/ar_pud-ud-test.txt
# ud-treebanks-v2.5/UD_Arabic-PUD/ar_pud-ud-test.conllu
# ud-treebanks-v2.5/UD_Arabic-PUD/LICENSE.txt
# ud-treebanks-v2.5/UD_Arabic-PUD/stats.xml
# ud-treebanks-v2.5/UD_Swedish_Sign_Language-SSLC/
# ud-treebanks-v2.5/UD_Swedish_Sign_Language-SSLC/swl_sslc-ud-dev.txt
# ud-treebanks-v2.5/UD_Swedish_Sign_Language-SSLC/swl_sslc-ud-dev.conllu
# ud-treebanks-v2.5/UD_Swedish_Sign_Language-SSLC/swl_sslc-ud-test.conllu
# ud-treebanks-v2.5/UD_Swedish_Sign_Language-SSLC/swl_sslc-ud-train.txt
# ud-treebanks-v2.5/UD_Swedish_Sign_Language-SSLC/LICENSE.txt
# ud-treebanks-v2.5/UD_Swedish_Sign_Language-SSLC/README.md
# ud-treebanks-v2.5/UD_Swedish_Sign_Language-SSLC/stats.xml
# ud-treebanks-v2.5/UD_Swedish_Sign_Language-SSLC/swl_sslc-ud-test.txt
# ud-treebanks-v2.5/UD_Swedish_Sign_Language-SSLC/swl_sslc-ud-train.conllu
# ud-treebanks-v2.5/UD_Croatian-SET/
# ud-treebanks-v2.5/UD_Croatian-SET/README.md
# ud-treebanks-v2.5/UD_Croatian-SET/hr_set-ud-dev.txt
# ud-treebanks-v2.5/UD_Croatian-SET/hr_set-ud-test.conllu
# ud-treebanks-v2.5/UD_Croatian-SET/hr_set-ud-train.conllu
# ud-treebanks-v2.5/UD_Croatian-SET/hr_set-ud-dev.conllu
# ud-treebanks-v2.5/UD_Croatian-SET/hr_set-ud-train.txt
# ud-treebanks-v2.5/UD_Croatian-SET/stats.xml
# ud-treebanks-v2.5/UD_Croatian-SET/hr_set-ud-test.txt
# ud-treebanks-v2.5/UD_Croatian-SET/LICENSE.txt
# ud-treebanks-v2.5/UD_Tamil-TTB/
# ud-treebanks-v2.5/UD_Tamil-TTB/ta_ttb-ud-train.conllu
# ud-treebanks-v2.5/UD_Tamil-TTB/stats.xml
# ud-treebanks-v2.5/UD_Tamil-TTB/ta_ttb-ud-dev.conllu
# ud-treebanks-v2.5/UD_Tamil-TTB/LICENSE.txt
# ud-treebanks-v2.5/UD_Tamil-TTB/README.md
# ud-treebanks-v2.5/UD_Tamil-TTB/ta_ttb-ud-test.txt
# ud-treebanks-v2.5/UD_Tamil-TTB/ta_ttb-ud-train.txt
# ud-treebanks-v2.5/UD_Tamil-TTB/ta_ttb-ud-dev.txt
# ud-treebanks-v2.5/UD_Tamil-TTB/ta_ttb-ud-test.conllu
# ud-treebanks-v2.5/UD_Wolof-WTB/
# ud-treebanks-v2.5/UD_Wolof-WTB/wo_wtb-ud-test.txt
# ud-treebanks-v2.5/UD_Wolof-WTB/README.md
# ud-treebanks-v2.5/UD_Wolof-WTB/wo_wtb-ud-test.conllu
# ud-treebanks-v2.5/UD_Wolof-WTB/wo_wtb-ud-dev.conllu
# ud-treebanks-v2.5/UD_Wolof-WTB/wo_wtb-ud-train.txt
# ud-treebanks-v2.5/UD_Wolof-WTB/LICENSE.txt
# ud-treebanks-v2.5/UD_Wolof-WTB/wo_wtb-ud-dev.txt
# ud-treebanks-v2.5/UD_Wolof-WTB/wo_wtb-ud-train.conllu
# ud-treebanks-v2.5/UD_Wolof-WTB/stats.xml
# ud-treebanks-v2.5/UD_Livvi-KKPP/
# ud-treebanks-v2.5/UD_Livvi-KKPP/stats.xml
# ud-treebanks-v2.5/UD_Livvi-KKPP/olo_kkpp-ud-train.conllu
# ud-treebanks-v2.5/UD_Livvi-KKPP/olo_kkpp-ud-train.txt
# ud-treebanks-v2.5/UD_Livvi-KKPP/olo_kkpp-ud-test.conllu
# ud-treebanks-v2.5/UD_Livvi-KKPP/LICENSE.txt
# ud-treebanks-v2.5/UD_Livvi-KKPP/olo_kkpp-ud-test.txt
# ud-treebanks-v2.5/UD_Livvi-KKPP/README.md
# ud-treebanks-v2.5/UD_Spanish-AnCora/
# ud-treebanks-v2.5/UD_Spanish-AnCora/es_ancora-ud-dev.conllu
# ud-treebanks-v2.5/UD_Spanish-AnCora/es_ancora-ud-test.txt
# ud-treebanks-v2.5/UD_Spanish-AnCora/es_ancora-ud-train.txt
# ud-treebanks-v2.5/UD_Spanish-AnCora/es_ancora-ud-dev.txt
# ud-treebanks-v2.5/UD_Spanish-AnCora/README.md
# ud-treebanks-v2.5/UD_Spanish-AnCora/es_ancora-ud-test.conllu
# ud-treebanks-v2.5/UD_Spanish-AnCora/es_ancora-ud-train.conllu
# ud-treebanks-v2.5/UD_Spanish-AnCora/stats.xml
# ud-treebanks-v2.5/UD_Spanish-AnCora/LICENSE.txt
# ud-treebanks-v2.5/UD_Latvian-LVTB/
# ud-treebanks-v2.5/UD_Latvian-LVTB/lv_lvtb-ud-train.conllu
# ud-treebanks-v2.5/UD_Latvian-LVTB/lv_lvtb-ud-dev.conllu
# ud-treebanks-v2.5/UD_Latvian-LVTB/stats.xml
# ud-treebanks-v2.5/UD_Latvian-LVTB/LICENSE.txt
# ud-treebanks-v2.5/UD_Latvian-LVTB/lv_lvtb-ud-train.txt
# ud-treebanks-v2.5/UD_Latvian-LVTB/lv_lvtb-ud-dev.txt
# ud-treebanks-v2.5/UD_Latvian-LVTB/README.md
# ud-treebanks-v2.5/UD_Latvian-LVTB/lv_lvtb-ud-test.txt
# ud-treebanks-v2.5/UD_Latvian-LVTB/lv_lvtb-ud-test.conllu
# ud-treebanks-v2.5/UD_Classical_Chinese-Kyoto/
# ud-treebanks-v2.5/UD_Classical_Chinese-Kyoto/lzh_kyoto-ud-train.txt
# ud-treebanks-v2.5/UD_Classical_Chinese-Kyoto/lzh_kyoto-ud-dev.conllu
# ud-treebanks-v2.5/UD_Classical_Chinese-Kyoto/README.md
# ud-treebanks-v2.5/UD_Classical_Chinese-Kyoto/lzh_kyoto-ud-dev.txt
# ud-treebanks-v2.5/UD_Classical_Chinese-Kyoto/LICENSE.txt
# ud-treebanks-v2.5/UD_Classical_Chinese-Kyoto/stats.xml
# ud-treebanks-v2.5/UD_Classical_Chinese-Kyoto/lzh_kyoto-ud-test.txt
# ud-treebanks-v2.5/UD_Classical_Chinese-Kyoto/lzh_kyoto-ud-train.conllu
# ud-treebanks-v2.5/UD_Classical_Chinese-Kyoto/lzh_kyoto-ud-test.conllu
# ud-treebanks-v2.5/UD_Greek-GDT/
# ud-treebanks-v2.5/UD_Greek-GDT/el_gdt-ud-dev.conllu
# ud-treebanks-v2.5/UD_Greek-GDT/el_gdt-ud-train.conllu
# ud-treebanks-v2.5/UD_Greek-GDT/el_gdt-ud-dev.txt
# ud-treebanks-v2.5/UD_Greek-GDT/stats.xml
# ud-treebanks-v2.5/UD_Greek-GDT/el_gdt-ud-train.txt
# ud-treebanks-v2.5/UD_Greek-GDT/el_gdt-ud-test.conllu
# ud-treebanks-v2.5/UD_Greek-GDT/LICENSE.txt
# ud-treebanks-v2.5/UD_Greek-GDT/README.md
# ud-treebanks-v2.5/UD_Greek-GDT/el_gdt-ud-test.txt
# ud-treebanks-v2.5/UD_German-LIT/
# ud-treebanks-v2.5/UD_German-LIT/de_lit-ud-test.conllu
# ud-treebanks-v2.5/UD_German-LIT/stats.xml
# ud-treebanks-v2.5/UD_German-LIT/LICENSE.txt
# ud-treebanks-v2.5/UD_German-LIT/README.md
# ud-treebanks-v2.5/UD_German-LIT/de_lit-ud-test.txt
# ud-treebanks-v2.5/UD_Swiss_German-UZH/
# ud-treebanks-v2.5/UD_Swiss_German-UZH/README.md
# ud-treebanks-v2.5/UD_Swiss_German-UZH/LICENSE.txt
# ud-treebanks-v2.5/UD_Swiss_German-UZH/gsw_uzh-ud-test.conllu
# ud-treebanks-v2.5/UD_Swiss_German-UZH/gsw_uzh-ud-test.txt
# ud-treebanks-v2.5/UD_Swiss_German-UZH/stats.xml
# ud-treebanks-v2.5/UD_Dutch-LassySmall/
# ud-treebanks-v2.5/UD_Dutch-LassySmall/nl_lassysmall-ud-train.conllu
# ud-treebanks-v2.5/UD_Dutch-LassySmall/stats.xml
# ud-treebanks-v2.5/UD_Dutch-LassySmall/nl_lassysmall-ud-test.txt
# ud-treebanks-v2.5/UD_Dutch-LassySmall/nl_lassysmall-ud-dev.conllu
# ud-treebanks-v2.5/UD_Dutch-LassySmall/LICENSE.txt
# ud-treebanks-v2.5/UD_Dutch-LassySmall/README.txt
# ud-treebanks-v2.5/UD_Dutch-LassySmall/nl_lassysmall-ud-test.conllu
# ud-treebanks-v2.5/UD_Dutch-LassySmall/nl_lassysmall-ud-dev.txt
# ud-treebanks-v2.5/UD_Dutch-LassySmall/nl_lassysmall-ud-train.txt
# ud-treebanks-v2.5/UD_Slovak-SNK/
# ud-treebanks-v2.5/UD_Slovak-SNK/sk_snk-ud-dev.txt
# ud-treebanks-v2.5/UD_Slovak-SNK/stats.xml
# ud-treebanks-v2.5/UD_Slovak-SNK/sk_snk-ud-dev.conllu
# ud-treebanks-v2.5/UD_Slovak-SNK/sk_snk-ud-train.conllu
# ud-treebanks-v2.5/UD_Slovak-SNK/sk_snk-ud-test.txt
# ud-treebanks-v2.5/UD_Slovak-SNK/sk_snk-ud-test.conllu
# ud-treebanks-v2.5/UD_Slovak-SNK/LICENSE.txt
# ud-treebanks-v2.5/UD_Slovak-SNK/README.md
# ud-treebanks-v2.5/UD_Slovak-SNK/sk_snk-ud-train.txt
# ud-treebanks-v2.5/UD_Ancient_Greek-Perseus/
# ud-treebanks-v2.5/UD_Ancient_Greek-Perseus/grc_perseus-ud-train.conllu
# ud-treebanks-v2.5/UD_Ancient_Greek-Perseus/grc_perseus-ud-test.txt
# ud-treebanks-v2.5/UD_Ancient_Greek-Perseus/grc_perseus-ud-dev.conllu
# ud-treebanks-v2.5/UD_Ancient_Greek-Perseus/stats.xml
# ud-treebanks-v2.5/UD_Ancient_Greek-Perseus/grc_perseus-ud-train.txt
# ud-treebanks-v2.5/UD_Ancient_Greek-Perseus/LICENSE.txt
# ud-treebanks-v2.5/UD_Ancient_Greek-Perseus/grc_perseus-ud-dev.txt
# ud-treebanks-v2.5/UD_Ancient_Greek-Perseus/README.md
# ud-treebanks-v2.5/UD_Ancient_Greek-Perseus/grc_perseus-ud-test.conllu
# ud-treebanks-v2.5/UD_Italian-PUD/
# ud-treebanks-v2.5/UD_Italian-PUD/README.md
# ud-treebanks-v2.5/UD_Italian-PUD/it_pud-ud-test.txt
# ud-treebanks-v2.5/UD_Italian-PUD/it_pud-ud-test.conllu
# ud-treebanks-v2.5/UD_Italian-PUD/stats.xml
# ud-treebanks-v2.5/UD_Italian-PUD/LICENSE.txt
# ud-treebanks-v2.5/UD_Norwegian-Nynorsk/
# ud-treebanks-v2.5/UD_Norwegian-Nynorsk/no_nynorsk-ud-dev.conllu
# ud-treebanks-v2.5/UD_Norwegian-Nynorsk/stats.xml
# ud-treebanks-v2.5/UD_Norwegian-Nynorsk/no_nynorsk-ud-train.txt
# ud-treebanks-v2.5/UD_Norwegian-Nynorsk/no_nynorsk-ud-dev.txt
# ud-treebanks-v2.5/UD_Norwegian-Nynorsk/LICENSE.txt
# ud-treebanks-v2.5/UD_Norwegian-Nynorsk/no_nynorsk-ud-test.conllu
# ud-treebanks-v2.5/UD_Norwegian-Nynorsk/no_nynorsk-ud-train.conllu
# ud-treebanks-v2.5/UD_Norwegian-Nynorsk/README.md
# ud-treebanks-v2.5/UD_Norwegian-Nynorsk/no_nynorsk-ud-test.txt
# ud-treebanks-v2.5/UD_Lithuanian-HSE/
# ud-treebanks-v2.5/UD_Lithuanian-HSE/README.md
# ud-treebanks-v2.5/UD_Lithuanian-HSE/lt_hse-ud-test.conllu
# ud-treebanks-v2.5/UD_Lithuanian-HSE/lt_hse-ud-train.txt
# ud-treebanks-v2.5/UD_Lithuanian-HSE/lt_hse-ud-train.conllu
# ud-treebanks-v2.5/UD_Lithuanian-HSE/lt_hse-ud-dev.conllu
# ud-treebanks-v2.5/UD_Lithuanian-HSE/lt_hse-ud-test.txt
# ud-treebanks-v2.5/UD_Lithuanian-HSE/lt_hse-ud-dev.txt
# ud-treebanks-v2.5/UD_Lithuanian-HSE/stats.xml
# ud-treebanks-v2.5/UD_Lithuanian-HSE/LICENSE.txt
# ud-treebanks-v2.5/UD_Urdu-UDTB/
# ud-treebanks-v2.5/UD_Urdu-UDTB/ur_udtb-ud-train.txt
# ud-treebanks-v2.5/UD_Urdu-UDTB/README.md
# ud-treebanks-v2.5/UD_Urdu-UDTB/ur_udtb-ud-train.conllu
# ud-treebanks-v2.5/UD_Urdu-UDTB/LICENSE.txt
# ud-treebanks-v2.5/UD_Urdu-UDTB/ur_udtb-ud-dev.conllu
# ud-treebanks-v2.5/UD_Urdu-UDTB/ur_udtb-ud-test.conllu
# ud-treebanks-v2.5/UD_Urdu-UDTB/stats.xml
# ud-treebanks-v2.5/UD_Urdu-UDTB/ur_udtb-ud-test.txt
# ud-treebanks-v2.5/UD_Urdu-UDTB/ur_udtb-ud-dev.txt
# ud-treebanks-v2.5/UD_Indonesian-PUD/
# ud-treebanks-v2.5/UD_Indonesian-PUD/id_pud-ud-test.conllu
# ud-treebanks-v2.5/UD_Indonesian-PUD/README.md
# ud-treebanks-v2.5/UD_Indonesian-PUD/LICENSE.txt
# ud-treebanks-v2.5/UD_Indonesian-PUD/stats.xml
# ud-treebanks-v2.5/UD_Indonesian-PUD/id_pud-ud-test.txt
# ud-treebanks-v2.5/UD_Indonesian-GSD/
# ud-treebanks-v2.5/UD_Indonesian-GSD/stats.xml
# ud-treebanks-v2.5/UD_Indonesian-GSD/id_gsd-ud-dev.conllu
# ud-treebanks-v2.5/UD_Indonesian-GSD/id_gsd-ud-train.conllu
# ud-treebanks-v2.5/UD_Indonesian-GSD/id_gsd-ud-train.txt
# ud-treebanks-v2.5/UD_Indonesian-GSD/id_gsd-ud-dev.txt
# ud-treebanks-v2.5/UD_Indonesian-GSD/id_gsd-ud-test.txt
# ud-treebanks-v2.5/UD_Indonesian-GSD/README.md
# ud-treebanks-v2.5/UD_Indonesian-GSD/id_gsd-ud-test.conllu
# ud-treebanks-v2.5/UD_Indonesian-GSD/LICENSE.txt
# ud-treebanks-v2.5/UD_Italian-VIT/
# ud-treebanks-v2.5/UD_Italian-VIT/stats.xml
# ud-treebanks-v2.5/UD_Italian-VIT/it_vit-ud-test.txt
# ud-treebanks-v2.5/UD_Italian-VIT/it_vit-ud-test.conllu
# ud-treebanks-v2.5/UD_Italian-VIT/it_vit-ud-train.conllu
# ud-treebanks-v2.5/UD_Italian-VIT/LICENSE.txt
# ud-treebanks-v2.5/UD_Italian-VIT/it_vit-ud-train.txt
# ud-treebanks-v2.5/UD_Italian-VIT/it_vit-ud-dev.conllu
# ud-treebanks-v2.5/UD_Italian-VIT/it_vit-ud-dev.txt
# ud-treebanks-v2.5/UD_Italian-VIT/README.md
# ud-treebanks-v2.5/UD_Vietnamese-VTB/
# ud-treebanks-v2.5/UD_Vietnamese-VTB/README.md
# ud-treebanks-v2.5/UD_Vietnamese-VTB/vi_vtb-ud-dev.txt
# ud-treebanks-v2.5/UD_Vietnamese-VTB/vi_vtb-ud-train.conllu
# ud-treebanks-v2.5/UD_Vietnamese-VTB/vi_vtb-ud-train.txt
# ud-treebanks-v2.5/UD_Vietnamese-VTB/vi_vtb-ud-test.txt
# ud-treebanks-v2.5/UD_Vietnamese-VTB/vi_vtb-ud-test.conllu
# ud-treebanks-v2.5/UD_Vietnamese-VTB/LICENSE.txt
# ud-treebanks-v2.5/UD_Vietnamese-VTB/stats.xml
# ud-treebanks-v2.5/UD_Vietnamese-VTB/vi_vtb-ud-dev.conllu
# ud-treebanks-v2.5/UD_Komi_Permyak-UH/
# ud-treebanks-v2.5/UD_Komi_Permyak-UH/koi_uh-ud-test.conllu
# ud-treebanks-v2.5/UD_Komi_Permyak-UH/LICENSE.txt
# ud-treebanks-v2.5/UD_Komi_Permyak-UH/koi_uh-ud-test.txt
# ud-treebanks-v2.5/UD_Komi_Permyak-UH/README.md
# ud-treebanks-v2.5/UD_Komi_Permyak-UH/stats.xml
# ud-treebanks-v2.5/UD_Thai-PUD/
# ud-treebanks-v2.5/UD_Thai-PUD/th_pud-ud-test.txt
# ud-treebanks-v2.5/UD_Thai-PUD/README.md
# ud-treebanks-v2.5/UD_Thai-PUD/stats.xml
# ud-treebanks-v2.5/UD_Thai-PUD/th_pud-ud-test.conllu
# ud-treebanks-v2.5/UD_Thai-PUD/LICENSE.txt
# ud-treebanks-v2.5/UD_Finnish-TDT/
# ud-treebanks-v2.5/UD_Finnish-TDT/LICENSE.txt
# ud-treebanks-v2.5/UD_Finnish-TDT/fi_tdt-ud-train.conllu
# ud-treebanks-v2.5/UD_Finnish-TDT/fi_tdt-ud-dev.conllu
# ud-treebanks-v2.5/UD_Finnish-TDT/README.txt
# ud-treebanks-v2.5/UD_Finnish-TDT/fi_tdt-ud-dev.txt
# ud-treebanks-v2.5/UD_Finnish-TDT/fi_tdt-ud-test.txt
# ud-treebanks-v2.5/UD_Finnish-TDT/fi_tdt-ud-test.conllu
# ud-treebanks-v2.5/UD_Finnish-TDT/stats.xml
# ud-treebanks-v2.5/UD_Finnish-TDT/fi_tdt-ud-train.txt
# ud-treebanks-v2.5/UD_Danish-DDT/
# ud-treebanks-v2.5/UD_Danish-DDT/stats.xml
# ud-treebanks-v2.5/UD_Danish-DDT/da_ddt-ud-test.txt
# ud-treebanks-v2.5/UD_Danish-DDT/da_ddt-ud-test.conllu
# ud-treebanks-v2.5/UD_Danish-DDT/LICENSE.txt
# ud-treebanks-v2.5/UD_Danish-DDT/da_ddt-ud-train.conllu
# ud-treebanks-v2.5/UD_Danish-DDT/da_ddt-ud-dev.txt
# ud-treebanks-v2.5/UD_Danish-DDT/da_ddt-ud-dev.conllu
# ud-treebanks-v2.5/UD_Danish-DDT/README.md
# ud-treebanks-v2.5/UD_Danish-DDT/da_ddt-ud-train.txt
# ud-treebanks-v2.5/UD_Swedish-Talbanken/
# ud-treebanks-v2.5/UD_Swedish-Talbanken/LICENSE.txt
# ud-treebanks-v2.5/UD_Swedish-Talbanken/sv_talbanken-ud-train.conllu
# ud-treebanks-v2.5/UD_Swedish-Talbanken/stats.xml
# ud-treebanks-v2.5/UD_Swedish-Talbanken/sv_talbanken-ud-test.txt
# ud-treebanks-v2.5/UD_Swedish-Talbanken/README.md
# ud-treebanks-v2.5/UD_Swedish-Talbanken/sv_talbanken-ud-dev.txt
# ud-treebanks-v2.5/UD_Swedish-Talbanken/sv_talbanken-ud-dev.conllu
# ud-treebanks-v2.5/UD_Swedish-Talbanken/sv_talbanken-ud-train.txt
# ud-treebanks-v2.5/UD_Swedish-Talbanken/sv_talbanken-ud-test.conllu
# ud-treebanks-v2.5/UD_Korean-Kaist/
# ud-treebanks-v2.5/UD_Korean-Kaist/ko_kaist-ud-train.conllu
# ud-treebanks-v2.5/UD_Korean-Kaist/README.md
# ud-treebanks-v2.5/UD_Korean-Kaist/ko_kaist-ud-dev.conllu
# ud-treebanks-v2.5/UD_Korean-Kaist/ko_kaist-ud-test.conllu
# ud-treebanks-v2.5/UD_Korean-Kaist/ko_kaist-ud-train.txt
# ud-treebanks-v2.5/UD_Korean-Kaist/LICENSE.txt
# ud-treebanks-v2.5/UD_Korean-Kaist/ko_kaist-ud-test.txt
# ud-treebanks-v2.5/UD_Korean-Kaist/stats.xml
# ud-treebanks-v2.5/UD_Korean-Kaist/ko_kaist-ud-dev.txt
# ud-treebanks-v2.5/UD_Moksha-JR/
# ud-treebanks-v2.5/UD_Moksha-JR/stats.xml
# ud-treebanks-v2.5/UD_Moksha-JR/LICENSE.txt
# ud-treebanks-v2.5/UD_Moksha-JR/mdf_jr-ud-test.conllu
# ud-treebanks-v2.5/UD_Moksha-JR/mdf_jr-ud-test.txt
# ud-treebanks-v2.5/UD_Moksha-JR/README.md
# ud-treebanks-v2.5/UD_Arabic-NYUAD/
# ud-treebanks-v2.5/UD_Arabic-NYUAD/ar_nyuad-ud-train.conllu
# ud-treebanks-v2.5/UD_Arabic-NYUAD/stats.xml
# ud-treebanks-v2.5/UD_Arabic-NYUAD/ar_nyuad-ud-dev.txt
# ud-treebanks-v2.5/UD_Arabic-NYUAD/merge.jar
# ud-treebanks-v2.5/UD_Arabic-NYUAD/LICENSE.txt
# ud-treebanks-v2.5/UD_Arabic-NYUAD/ar_nyuad-ud-dev.conllu
# ud-treebanks-v2.5/UD_Arabic-NYUAD/ar_nyuad-ud-test.txt
# ud-treebanks-v2.5/UD_Arabic-NYUAD/ar_nyuad-ud-test.conllu
# ud-treebanks-v2.5/UD_Arabic-NYUAD/README.md
# ud-treebanks-v2.5/UD_Arabic-NYUAD/ar_nyuad-ud-train.txt
# ud-treebanks-v2.5/UD_Latin-PROIEL/
# ud-treebanks-v2.5/UD_Latin-PROIEL/README.md
# ud-treebanks-v2.5/UD_Latin-PROIEL/la_proiel-ud-train.conllu
# ud-treebanks-v2.5/UD_Latin-PROIEL/la_proiel-ud-train.txt
# ud-treebanks-v2.5/UD_Latin-PROIEL/la_proiel-ud-test.txt
# ud-treebanks-v2.5/UD_Latin-PROIEL/la_proiel-ud-dev.conllu
# ud-treebanks-v2.5/UD_Latin-PROIEL/LICENSE.txt
# ud-treebanks-v2.5/UD_Latin-PROIEL/stats.xml
# ud-treebanks-v2.5/UD_Latin-PROIEL/la_proiel-ud-dev.txt
# ud-treebanks-v2.5/UD_Latin-PROIEL/la_proiel-ud-test.conllu
# ud-treebanks-v2.5/UD_Bulgarian-BTB/
# ud-treebanks-v2.5/UD_Bulgarian-BTB/bg_btb-ud-train.conllu
# ud-treebanks-v2.5/UD_Bulgarian-BTB/bg_btb-ud-dev.txt
# ud-treebanks-v2.5/UD_Bulgarian-BTB/bg_btb-ud-dev.conllu
# ud-treebanks-v2.5/UD_Bulgarian-BTB/LICENSE.txt
# ud-treebanks-v2.5/UD_Bulgarian-BTB/README.txt
# ud-treebanks-v2.5/UD_Bulgarian-BTB/stats.xml
# ud-treebanks-v2.5/UD_Bulgarian-BTB/bg_btb-ud-test.txt
# ud-treebanks-v2.5/UD_Bulgarian-BTB/bg_btb-ud-test.conllu
# ud-treebanks-v2.5/UD_Bulgarian-BTB/bg_btb-ud-train.txt
# ud-treebanks-v2.5/UD_Gothic-PROIEL/
# ud-treebanks-v2.5/UD_Gothic-PROIEL/got_proiel-ud-train.conllu
# ud-treebanks-v2.5/UD_Gothic-PROIEL/stats.xml
# ud-treebanks-v2.5/UD_Gothic-PROIEL/got_proiel-ud-test.txt
# ud-treebanks-v2.5/UD_Gothic-PROIEL/got_proiel-ud-test.conllu
# ud-treebanks-v2.5/UD_Gothic-PROIEL/got_proiel-ud-dev.txt
# ud-treebanks-v2.5/UD_Gothic-PROIEL/LICENSE.txt
# ud-treebanks-v2.5/UD_Gothic-PROIEL/got_proiel-ud-train.txt
# ud-treebanks-v2.5/UD_Gothic-PROIEL/got_proiel-ud-dev.conllu
# ud-treebanks-v2.5/UD_Gothic-PROIEL/README.md
# ud-treebanks-v2.5/UD_English-ESL/
# ud-treebanks-v2.5/UD_English-ESL/stats.xml
# ud-treebanks-v2.5/UD_English-ESL/en_esl-ud-dev.txt
# ud-treebanks-v2.5/UD_English-ESL/en_esl-ud-train.txt
# ud-treebanks-v2.5/UD_English-ESL/en_esl-ud-test.conllu
# ud-treebanks-v2.5/UD_English-ESL/merge.py
# ud-treebanks-v2.5/UD_English-ESL/en_esl-ud-train.conllu
# ud-treebanks-v2.5/UD_English-ESL/LICENSE.txt
# ud-treebanks-v2.5/UD_English-ESL/en_esl-ud-test.txt
# ud-treebanks-v2.5/UD_English-ESL/README.md
# ud-treebanks-v2.5/UD_English-ESL/en_esl-ud-dev.conllu
# ud-treebanks-v2.5/UD_Cantonese-HK/
# ud-treebanks-v2.5/UD_Cantonese-HK/README.md
# ud-treebanks-v2.5/UD_Cantonese-HK/LICENSE.txt
# ud-treebanks-v2.5/UD_Cantonese-HK/stats.xml
# ud-treebanks-v2.5/UD_Cantonese-HK/yue_hk-ud-test.txt
# ud-treebanks-v2.5/UD_Cantonese-HK/yue_hk-ud-test.conllu
# ud-treebanks-v2.5/UD_Tagalog-TRG/
# ud-treebanks-v2.5/UD_Tagalog-TRG/tl_trg-ud-test.txt
# ud-treebanks-v2.5/UD_Tagalog-TRG/stats.xml
# ud-treebanks-v2.5/UD_Tagalog-TRG/README.md
# ud-treebanks-v2.5/UD_Tagalog-TRG/tl_trg-ud-test.conllu
# ud-treebanks-v2.5/UD_Tagalog-TRG/LICENSE.txt
# ud-treebanks-v2.5/UD_Akkadian-PISANDUB/
# ud-treebanks-v2.5/UD_Akkadian-PISANDUB/README.md
# ud-treebanks-v2.5/UD_Akkadian-PISANDUB/akk_pisandub-ud-test.txt
# ud-treebanks-v2.5/UD_Akkadian-PISANDUB/akk_pisandub-ud-test.conllu
# ud-treebanks-v2.5/UD_Akkadian-PISANDUB/stats.xml
# ud-treebanks-v2.5/UD_Akkadian-PISANDUB/LICENSE.txt
# ud-treebanks-v2.5/UD_Czech-PUD/
# ud-treebanks-v2.5/UD_Czech-PUD/LICENSE.txt
# ud-treebanks-v2.5/UD_Czech-PUD/cs_pud-ud-test.txt
# ud-treebanks-v2.5/UD_Czech-PUD/stats.xml
# ud-treebanks-v2.5/UD_Czech-PUD/cs_pud-ud-test.conllu
# ud-treebanks-v2.5/UD_Czech-PUD/README.md
# ud-treebanks-v2.5/UD_Coptic-Scriptorium/
# ud-treebanks-v2.5/UD_Coptic-Scriptorium/cop_scriptorium-ud-dev.conllu
# ud-treebanks-v2.5/UD_Coptic-Scriptorium/cop_scriptorium-ud-train.conllu
# ud-treebanks-v2.5/UD_Coptic-Scriptorium/cop_scriptorium-ud-dev.txt
# ud-treebanks-v2.5/UD_Coptic-Scriptorium/README.md
# ud-treebanks-v2.5/UD_Coptic-Scriptorium/LICENSE.txt
# ud-treebanks-v2.5/UD_Coptic-Scriptorium/cop_scriptorium-ud-test.txt
# ud-treebanks-v2.5/UD_Coptic-Scriptorium/stats.xml
# ud-treebanks-v2.5/UD_Coptic-Scriptorium/cop_scriptorium-ud-train.txt
# ud-treebanks-v2.5/UD_Coptic-Scriptorium/cop_scriptorium-ud-test.conllu
# ud-treebanks-v2.5/UD_Uyghur-UDT/
# ud-treebanks-v2.5/UD_Uyghur-UDT/stats.xml
# ud-treebanks-v2.5/UD_Uyghur-UDT/ug_udt-ud-dev.conllu
# ud-treebanks-v2.5/UD_Uyghur-UDT/ug_udt-ud-dev.txt
# ud-treebanks-v2.5/UD_Uyghur-UDT/LICENSE.txt
# ud-treebanks-v2.5/UD_Uyghur-UDT/ug_udt-ud-train.txt
# ud-treebanks-v2.5/UD_Uyghur-UDT/README.md
# ud-treebanks-v2.5/UD_Uyghur-UDT/ug_udt-ud-test.txt
# ud-treebanks-v2.5/UD_Uyghur-UDT/ug_udt-ud-train.conllu
# ud-treebanks-v2.5/UD_Uyghur-UDT/ug_udt-ud-test.conllu
# ud-treebanks-v2.5/UD_Hungarian-Szeged/
# ud-treebanks-v2.5/UD_Hungarian-Szeged/README.txt
# ud-treebanks-v2.5/UD_Hungarian-Szeged/hu_szeged-ud-train.conllu
# ud-treebanks-v2.5/UD_Hungarian-Szeged/LICENSE.txt
# ud-treebanks-v2.5/UD_Hungarian-Szeged/hu_szeged-ud-dev.txt
# ud-treebanks-v2.5/UD_Hungarian-Szeged/hu_szeged-ud-dev.conllu
# ud-treebanks-v2.5/UD_Hungarian-Szeged/stats.xml
# ud-treebanks-v2.5/UD_Hungarian-Szeged/hu_szeged-ud-train.txt
# ud-treebanks-v2.5/UD_Hungarian-Szeged/hu_szeged-ud-test.txt
# ud-treebanks-v2.5/UD_Hungarian-Szeged/hu_szeged-ud-test.conllu
# ud-treebanks-v2.5/UD_Komi_Zyrian-IKDP/
# ud-treebanks-v2.5/UD_Komi_Zyrian-IKDP/stats.xml
# ud-treebanks-v2.5/UD_Komi_Zyrian-IKDP/kpv_ikdp-ud-test.txt
# ud-treebanks-v2.5/UD_Komi_Zyrian-IKDP/kpv_ikdp-ud-test.conllu
# ud-treebanks-v2.5/UD_Komi_Zyrian-IKDP/README.md
# ud-treebanks-v2.5/UD_Komi_Zyrian-IKDP/LICENSE.txt
# ud-treebanks-v2.5/UD_Belarusian-HSE/
# ud-treebanks-v2.5/UD_Belarusian-HSE/README.md
# ud-treebanks-v2.5/UD_Belarusian-HSE/be_hse-ud-dev.txt
# ud-treebanks-v2.5/UD_Belarusian-HSE/be_hse-ud-train.conllu
# ud-treebanks-v2.5/UD_Belarusian-HSE/be_hse-ud-test.conllu
# ud-treebanks-v2.5/UD_Belarusian-HSE/LICENSE.txt
# ud-treebanks-v2.5/UD_Belarusian-HSE/be_hse-ud-test.txt
# ud-treebanks-v2.5/UD_Belarusian-HSE/be_hse-ud-train.txt
# ud-treebanks-v2.5/UD_Belarusian-HSE/stats.xml
# ud-treebanks-v2.5/UD_Belarusian-HSE/be_hse-ud-dev.conllu
# ud-treebanks-v2.5/UD_Norwegian-Bokmaal/
# ud-treebanks-v2.5/UD_Norwegian-Bokmaal/no_bokmaal-ud-test.txt
# ud-treebanks-v2.5/UD_Norwegian-Bokmaal/LICENSE.txt
# ud-treebanks-v2.5/UD_Norwegian-Bokmaal/no_bokmaal-ud-dev.txt
# ud-treebanks-v2.5/UD_Norwegian-Bokmaal/README.md
# ud-treebanks-v2.5/UD_Norwegian-Bokmaal/no_bokmaal-ud-test.conllu
# ud-treebanks-v2.5/UD_Norwegian-Bokmaal/stats.xml
# ud-treebanks-v2.5/UD_Norwegian-Bokmaal/no_bokmaal-ud-dev.conllu
# ud-treebanks-v2.5/UD_Norwegian-Bokmaal/no_bokmaal-ud-train.txt
# ud-treebanks-v2.5/UD_Norwegian-Bokmaal/no_bokmaal-ud-train.conllu
# ud-treebanks-v2.5/UD_Kazakh-KTB/
# ud-treebanks-v2.5/UD_Kazakh-KTB/kk_ktb-ud-test.txt
# ud-treebanks-v2.5/UD_Kazakh-KTB/stats.xml
# ud-treebanks-v2.5/UD_Kazakh-KTB/kk_ktb-ud-test.conllu
# ud-treebanks-v2.5/UD_Kazakh-KTB/kk_ktb-ud-train.conllu
# ud-treebanks-v2.5/UD_Kazakh-KTB/LICENSE.txt
# ud-treebanks-v2.5/UD_Kazakh-KTB/README.txt
# ud-treebanks-v2.5/UD_Kazakh-KTB/kk_ktb-ud-train.txt
# ud-treebanks-v2.5/UD_Lithuanian-ALKSNIS/
# ud-treebanks-v2.5/UD_Lithuanian-ALKSNIS/lt_alksnis-ud-train.txt
# ud-treebanks-v2.5/UD_Lithuanian-ALKSNIS/lt_alksnis-ud-dev.conllu
# ud-treebanks-v2.5/UD_Lithuanian-ALKSNIS/README.md
# ud-treebanks-v2.5/UD_Lithuanian-ALKSNIS/stats.xml
# ud-treebanks-v2.5/UD_Lithuanian-ALKSNIS/LICENSE.txt
# ud-treebanks-v2.5/UD_Lithuanian-ALKSNIS/lt_alksnis-ud-train.conllu
# ud-treebanks-v2.5/UD_Lithuanian-ALKSNIS/lt_alksnis-ud-test.conllu
# ud-treebanks-v2.5/UD_Lithuanian-ALKSNIS/lt_alksnis-ud-dev.txt
# ud-treebanks-v2.5/UD_Lithuanian-ALKSNIS/lt_alksnis-ud-test.txt
# ud-treebanks-v2.5/UD_Czech-PDT/
# ud-treebanks-v2.5/UD_Czech-PDT/cs_pdt-ud-train.txt
# ud-treebanks-v2.5/UD_Czech-PDT/cs_pdt-ud-dev.txt
# ud-treebanks-v2.5/UD_Czech-PDT/LICENSE.txt
# ud-treebanks-v2.5/UD_Czech-PDT/README.md
# ud-treebanks-v2.5/UD_Czech-PDT/cs_pdt-ud-test.txt
# ud-treebanks-v2.5/UD_Czech-PDT/stats.xml
# ud-treebanks-v2.5/UD_Czech-PDT/cs_pdt-ud-dev.conllu
# ud-treebanks-v2.5/UD_Czech-PDT/cs_pdt-ud-train.conllu
# ud-treebanks-v2.5/UD_Czech-PDT/cs_pdt-ud-test.conllu
# ud-treebanks-v2.5/UD_Turkish-GB/
# ud-treebanks-v2.5/UD_Turkish-GB/README.md
# ud-treebanks-v2.5/UD_Turkish-GB/LICENSE.txt
# ud-treebanks-v2.5/UD_Turkish-GB/tr_gb-ud-test.txt
# ud-treebanks-v2.5/UD_Turkish-GB/stats.xml
# ud-treebanks-v2.5/UD_Turkish-GB/tr_gb-ud-test.conllu
# ud-treebanks-v2.5/UD_Mbya_Guarani-Dooley/
# ud-treebanks-v2.5/UD_Mbya_Guarani-Dooley/stats.xml
# ud-treebanks-v2.5/UD_Mbya_Guarani-Dooley/LICENSE.txt
# ud-treebanks-v2.5/UD_Mbya_Guarani-Dooley/gun_dooley-ud-test.conllu
# ud-treebanks-v2.5/UD_Mbya_Guarani-Dooley/gun_dooley-ud-test.txt
# ud-treebanks-v2.5/UD_Mbya_Guarani-Dooley/README.md
# ud-treebanks-v2.5/UD_Ancient_Greek-PROIEL/
# ud-treebanks-v2.5/UD_Ancient_Greek-PROIEL/LICENSE.txt
# ud-treebanks-v2.5/UD_Ancient_Greek-PROIEL/grc_proiel-ud-test.conllu
# ud-treebanks-v2.5/UD_Ancient_Greek-PROIEL/grc_proiel-ud-train.conllu
# ud-treebanks-v2.5/UD_Ancient_Greek-PROIEL/grc_proiel-ud-dev.txt
# ud-treebanks-v2.5/UD_Ancient_Greek-PROIEL/README.md
# ud-treebanks-v2.5/UD_Ancient_Greek-PROIEL/stats.xml
# ud-treebanks-v2.5/UD_Ancient_Greek-PROIEL/grc_proiel-ud-test.txt
# ud-treebanks-v2.5/UD_Ancient_Greek-PROIEL/grc_proiel-ud-train.txt
# ud-treebanks-v2.5/UD_Ancient_Greek-PROIEL/grc_proiel-ud-dev.conllu
# ud-treebanks-v2.5/UD_Kurmanji-MG/
# ...
# ud-treebanks-v2.5/UD_Armenian-ArmTDP/hy_armtdp-ud-test.txt
# ud-treebanks-v2.5/UD_Armenian-ArmTDP/hy_armtdp-ud-train.conllu
# ud-treebanks-v2.5/UD_Romanian-Nonstandard/
# ud-treebanks-v2.5/UD_Romanian-Nonstandard/ro_nonstandard-ud-train.conllu
# ud-treebanks-v2.5/UD_Romanian-Nonstandard/stats.xml
# ud-treebanks-v2.5/UD_Romanian-Nonstandard/LICENSE.txt
# ud-treebanks-v2.5/UD_Romanian-Nonstandard/ro_nonstandard-ud-dev.txt
# ud-treebanks-v2.5/UD_Romanian-Nonstandard/README.md
# ud-treebanks-v2.5/UD_Romanian-Nonstandard/ro_nonstandard-ud-test.txt
# ud-treebanks-v2.5/UD_Romanian-Nonstandard/ro_nonstandard-ud-dev.conllu
# ud-treebanks-v2.5/UD_Romanian-Nonstandard/ro_nonstandard-ud-train.txt
# ud-treebanks-v2.5/UD_Romanian-Nonstandard/ro_nonstandard-ud-test.conllu
# ud-treebanks-v2.5/UD_English-LinES/
# ud-treebanks-v2.5/UD_English-LinES/LICENSE.txt
# ud-treebanks-v2.5/UD_English-LinES/en_lines-ud-train.conllu
# ud-treebanks-v2.5/UD_English-LinES/stats.xml
# ud-treebanks-v2.5/UD_English-LinES/en_lines-ud-train.txt
# ud-treebanks-v2.5/UD_English-LinES/README.txt
# ud-treebanks-v2.5/UD_English-LinES/en_lines-ud-dev.txt
# ud-treebanks-v2.5/UD_English-LinES/en_lines-ud-test.conllu
# ud-treebanks-v2.5/UD_English-LinES/en_lines-ud-test.txt
# ud-treebanks-v2.5/UD_English-LinES/en_lines-ud-dev.conllu
# ud-treebanks-v2.5/UD_Old_French-SRCMF/
# ud-treebanks-v2.5/UD_Old_French-SRCMF/fro_srcmf-ud-test.conllu
# ud-treebanks-v2.5/UD_Old_French-SRCMF/fro_srcmf-ud-train.conllu
# ud-treebanks-v2.5/UD_Old_French-SRCMF/fro_srcmf-ud-test.txt
# ud-treebanks-v2.5/UD_Old_French-SRCMF/fro_srcmf-ud-train.txt
# ud-treebanks-v2.5/UD_Old_French-SRCMF/fro_srcmf-ud-dev.txt
# ud-treebanks-v2.5/UD_Old_French-SRCMF/README.md
# ud-treebanks-v2.5/UD_Old_French-SRCMF/fro_srcmf-ud-dev.conllu
# ud-treebanks-v2.5/UD_Old_French-SRCMF/stats.xml
# ud-treebanks-v2.5/UD_Old_French-SRCMF/LICENSE.txt
# ud-treebanks-v2.5/UD_North_Sami-Giella/
# ud-treebanks-v2.5/UD_North_Sami-Giella/sme_giella-ud-train.txt
# ud-treebanks-v2.5/UD_North_Sami-Giella/stats.xml
# ud-treebanks-v2.5/UD_North_Sami-Giella/sme_giella-ud-test.conllu
# ud-treebanks-v2.5/UD_North_Sami-Giella/LICENSE.txt
# ud-treebanks-v2.5/UD_North_Sami-Giella/sme_giella-ud-test.txt
# ud-treebanks-v2.5/UD_North_Sami-Giella/sme_giella-ud-train.conllu
# ud-treebanks-v2.5/UD_North_Sami-Giella/README.md
# ud-treebanks-v2.5/UD_Turkish-IMST/
# ud-treebanks-v2.5/UD_Turkish-IMST/tr_imst-ud-test.conllu
# ud-treebanks-v2.5/UD_Turkish-IMST/README.md
# ud-treebanks-v2.5/UD_Turkish-IMST/tr_imst-ud-dev.conllu
# ud-treebanks-v2.5/UD_Turkish-IMST/tr_imst-ud-dev.txt
# ud-treebanks-v2.5/UD_Turkish-IMST/LICENSE.txt
# ud-treebanks-v2.5/UD_Turkish-IMST/tr_imst-ud-train.txt
# ud-treebanks-v2.5/UD_Turkish-IMST/tr_imst-ud-test.txt
# ud-treebanks-v2.5/UD_Turkish-IMST/stats.xml
# ud-treebanks-v2.5/UD_Turkish-IMST/tr_imst-ud-train.conllu
# ud-treebanks-v2.5/UD_Basque-BDT/
# ud-treebanks-v2.5/UD_Basque-BDT/eu_bdt-ud-train.conllu
# ud-treebanks-v2.5/UD_Basque-BDT/eu_bdt-ud-dev.txt
# ud-treebanks-v2.5/UD_Basque-BDT/eu_bdt-ud-train.txt
# ud-treebanks-v2.5/UD_Basque-BDT/LICENSE.txt
# ud-treebanks-v2.5/UD_Basque-BDT/README.txt
# ud-treebanks-v2.5/UD_Basque-BDT/eu_bdt-ud-dev.conllu
# ud-treebanks-v2.5/UD_Basque-BDT/eu_bdt-ud-test.conllu
# ud-treebanks-v2.5/UD_Basque-BDT/eu_bdt-ud-test.txt
# ud-treebanks-v2.5/UD_Basque-BDT/stats.xml
# ud-treebanks-v2.5/UD_Chinese-CFL/
# ud-treebanks-v2.5/UD_Chinese-CFL/README.txt
# ud-treebanks-v2.5/UD_Chinese-CFL/LICENSE.txt
# ud-treebanks-v2.5/UD_Chinese-CFL/zh_cfl-ud-test.conllu
# ud-treebanks-v2.5/UD_Chinese-CFL/stats.xml
# ud-treebanks-v2.5/UD_Chinese-CFL/zh_cfl-ud-test.conllux
# ud-treebanks-v2.5/UD_Chinese-CFL/zh_cfl-ud-test.txt
# ud-treebanks-v2.5/UD_Latin-Perseus/
# ud-treebanks-v2.5/UD_Latin-Perseus/la_perseus-ud-test.conllu
# ud-treebanks-v2.5/UD_Latin-Perseus/README.md
# ud-treebanks-v2.5/UD_Latin-Perseus/la_perseus-ud-train.txt
# ud-treebanks-v2.5/UD_Latin-Perseus/LICENSE.txt
# ud-treebanks-v2.5/UD_Latin-Perseus/la_perseus-ud-train.conllu
# ud-treebanks-v2.5/UD_Latin-Perseus/la_perseus-ud-test.txt
# ud-treebanks-v2.5/UD_Latin-Perseus/stats.xml
# ud-treebanks-v2.5/UD_Karelian-KKPP/
# ud-treebanks-v2.5/UD_Karelian-KKPP/krl_kkpp-ud-test.conllu
# ud-treebanks-v2.5/UD_Karelian-KKPP/README.md
# ud-treebanks-v2.5/UD_Karelian-KKPP/LICENSE.txt
# ud-treebanks-v2.5/UD_Karelian-KKPP/stats.xml
# ud-treebanks-v2.5/UD_Karelian-KKPP/krl_kkpp-ud-test.txt
# ud-treebanks-v2.5/UD_Ukrainian-IU/
# ud-treebanks-v2.5/UD_Ukrainian-IU/uk_iu-ud-test.conllu
# ud-treebanks-v2.5/UD_Ukrainian-IU/LICENSE.txt
# ud-treebanks-v2.5/UD_Ukrainian-IU/stats.xml
# ud-treebanks-v2.5/UD_Ukrainian-IU/uk_iu-ud-train.txt
# ud-treebanks-v2.5/UD_Ukrainian-IU/README.md
# ud-treebanks-v2.5/UD_Ukrainian-IU/uk_iu-ud-train.conllu
# ud-treebanks-v2.5/UD_Ukrainian-IU/uk_iu-ud-test.txt
# ud-treebanks-v2.5/UD_Ukrainian-IU/uk_iu-ud-dev.conllu
# ud-treebanks-v2.5/UD_Ukrainian-IU/uk_iu-ud-dev.txt
# ud-treebanks-v2.5/UD_Italian-ISDT/
# ud-treebanks-v2.5/UD_Italian-ISDT/it_isdt-ud-test.conllu
# ud-treebanks-v2.5/UD_Italian-ISDT/it_isdt-ud-dev.txt
# ud-treebanks-v2.5/UD_Italian-ISDT/it_isdt-ud-train.txt
# ud-treebanks-v2.5/UD_Italian-ISDT/LICENSE.txt
# ud-treebanks-v2.5/UD_Italian-ISDT/stats.xml
# ud-treebanks-v2.5/UD_Italian-ISDT/it_isdt-ud-dev.conllu
# ud-treebanks-v2.5/UD_Italian-ISDT/it_isdt-ud-test.txt
# ud-treebanks-v2.5/UD_Italian-ISDT/README.md
# ud-treebanks-v2.5/UD_Italian-ISDT/it_isdt-ud-train.conllu
# ud-treebanks-v2.5/UD_Finnish-FTB/
# ud-treebanks-v2.5/UD_Finnish-FTB/stats.xml
# ud-treebanks-v2.5/UD_Finnish-FTB/LICENSE.txt
# ud-treebanks-v2.5/UD_Finnish-FTB/fi_ftb-ud-test.conllu
# ud-treebanks-v2.5/UD_Finnish-FTB/fi_ftb-ud-dev.conllu
# ud-treebanks-v2.5/UD_Finnish-FTB/README.md
# ud-treebanks-v2.5/UD_Finnish-FTB/fi_ftb-ud-train.conllu
# ud-treebanks-v2.5/UD_Finnish-FTB/fi_ftb-ud-train.txt
# ud-treebanks-v2.5/UD_Finnish-FTB/fi_ftb-ud-dev.txt
# ud-treebanks-v2.5/UD_Finnish-FTB/fi_ftb-ud-test.txt
# ud-treebanks-v2.5/UD_Turkish-PUD/
# ud-treebanks-v2.5/UD_Turkish-PUD/LICENSE.txt
# ud-treebanks-v2.5/UD_Turkish-PUD/stats.xml
# ud-treebanks-v2.5/UD_Turkish-PUD/README.md
# ud-treebanks-v2.5/UD_Turkish-PUD/tr_pud-ud-test.conllu
# ud-treebanks-v2.5/UD_Turkish-PUD/tr_pud-ud-test.txt
# ud-treebanks-v2.5/UD_Persian-Seraji/
# ud-treebanks-v2.5/UD_Persian-Seraji/README.md
# ud-treebanks-v2.5/UD_Persian-Seraji/fa_seraji-ud-dev.txt
# ud-treebanks-v2.5/UD_Persian-Seraji/LICENSE.txt
# ud-treebanks-v2.5/UD_Persian-Seraji/fa_seraji-ud-train.conllu
# ud-treebanks-v2.5/UD_Persian-Seraji/fa_seraji-ud-train.txt
# ud-treebanks-v2.5/UD_Persian-Seraji/fa_seraji-ud-test.txt
# ud-treebanks-v2.5/UD_Persian-Seraji/stats.xml
# ud-treebanks-v2.5/UD_Persian-Seraji/fa_seraji-ud-dev.conllu
# ud-treebanks-v2.5/UD_Persian-Seraji/fa_seraji-ud-test.conllu
# ud-treebanks-v2.5/UD_Polish-PUD/
# ud-treebanks-v2.5/UD_Polish-PUD/README.md
# ud-treebanks-v2.5/UD_Polish-PUD/pl_pud-ud-test.txt
# ud-treebanks-v2.5/UD_Polish-PUD/stats.xml
# ud-treebanks-v2.5/UD_Polish-PUD/LICENSE.txt
# ud-treebanks-v2.5/UD_Polish-PUD/pl_pud-ud-test.conllu
# ud-treebanks-v2.5/UD_Yoruba-YTB/
# ud-treebanks-v2.5/UD_Yoruba-YTB/LICENSE.txt
# ud-treebanks-v2.5/UD_Yoruba-YTB/stats.xml
# ud-treebanks-v2.5/UD_Yoruba-YTB/README.md
# ud-treebanks-v2.5/UD_Yoruba-YTB/yo_ytb-ud-test.conllu
# ud-treebanks-v2.5/UD_Yoruba-YTB/yo_ytb-ud-test.txt
# ud-treebanks-v2.5/UD_Norwegian-NynorskLIA/
# ud-treebanks-v2.5/UD_Norwegian-NynorskLIA/no_nynorsklia-ud-dev.conllu
# ud-treebanks-v2.5/UD_Norwegian-NynorskLIA/no_nynorsklia-ud-dev.txt
# ud-treebanks-v2.5/UD_Norwegian-NynorskLIA/no_nynorsklia-ud-train.conllu
# ud-treebanks-v2.5/UD_Norwegian-NynorskLIA/no_nynorsklia-ud-train.txt
# ud-treebanks-v2.5/UD_Norwegian-NynorskLIA/LICENSE.txt
# ud-treebanks-v2.5/UD_Norwegian-NynorskLIA/README.txt
# ud-treebanks-v2.5/UD_Norwegian-NynorskLIA/stats.xml
# ud-treebanks-v2.5/UD_Norwegian-NynorskLIA/no_nynorsklia-ud-test.txt
# ud-treebanks-v2.5/UD_Norwegian-NynorskLIA/no_nynorsklia-ud-test.conllu
# ud-treebanks-v2.5/UD_Amharic-ATT/
# ud-treebanks-v2.5/UD_Amharic-ATT/README.md
# ud-treebanks-v2.5/UD_Amharic-ATT/am_att-ud-test.txt
# ud-treebanks-v2.5/UD_Amharic-ATT/am_att-ud-test.conllu
# ud-treebanks-v2.5/UD_Amharic-ATT/LICENSE.txt
# ud-treebanks-v2.5/UD_Amharic-ATT/stats.xml
# ud-treebanks-v2.5/UD_Sanskrit-UFAL/
# ud-treebanks-v2.5/UD_Sanskrit-UFAL/LICENSE.txt
# ud-treebanks-v2.5/UD_Sanskrit-UFAL/sa_ufal-ud-test.conllu
# ud-treebanks-v2.5/UD_Sanskrit-UFAL/README.md
# ud-treebanks-v2.5/UD_Sanskrit-UFAL/sa_ufal-ud-test.txt
# ud-treebanks-v2.5/UD_Sanskrit-UFAL/stats.xml
# ud-treebanks-v2.5/UD_English-EWT/
# ud-treebanks-v2.5/UD_English-EWT/en_ewt-ud-test.txt
# ud-treebanks-v2.5/UD_English-EWT/en_ewt-ud-train.txt
# ud-treebanks-v2.5/UD_English-EWT/en_ewt-ud-train.conllu
# ud-treebanks-v2.5/UD_English-EWT/en_ewt-ud-dev.conllu
# ud-treebanks-v2.5/UD_English-EWT/LICENSE.txt
# ud-treebanks-v2.5/UD_English-EWT/stats.xml
# ud-treebanks-v2.5/UD_English-EWT/en_ewt-ud-test.conllu
# ud-treebanks-v2.5/UD_English-EWT/en_ewt-ud-dev.txt
# ud-treebanks-v2.5/UD_English-EWT/README.md
# ud-treebanks-v2.5/UD_Komi_Zyrian-Lattice/
# ud-treebanks-v2.5/UD_Komi_Zyrian-Lattice/README.md
# ud-treebanks-v2.5/UD_Komi_Zyrian-Lattice/kpv_lattice-ud-test.conllu
# ud-treebanks-v2.5/UD_Komi_Zyrian-Lattice/stats.xml
# ud-treebanks-v2.5/UD_Komi_Zyrian-Lattice/kpv_lattice-ud-test.txt
# ud-treebanks-v2.5/UD_Komi_Zyrian-Lattice/LICENSE.txt
# ud-treebanks-v2.5/UD_Upper_Sorbian-UFAL/
# ud-treebanks-v2.5/UD_Upper_Sorbian-UFAL/hsb_ufal-ud-test.conllu
# ud-treebanks-v2.5/UD_Upper_Sorbian-UFAL/stats.xml
# ud-treebanks-v2.5/UD_Upper_Sorbian-UFAL/hsb_ufal-ud-test.txt
# ud-treebanks-v2.5/UD_Upper_Sorbian-UFAL/hsb_ufal-ud-train.txt
# ud-treebanks-v2.5/UD_Upper_Sorbian-UFAL/LICENSE.txt
# ud-treebanks-v2.5/UD_Upper_Sorbian-UFAL/README.md
# ud-treebanks-v2.5/UD_Upper_Sorbian-UFAL/hsb_ufal-ud-train.conllu
# ud-treebanks-v2.5/UD_Chinese-GSDSimp/
# ud-treebanks-v2.5/UD_Chinese-GSDSimp/zh_gsdsimp-ud-test.conllu
# ud-treebanks-v2.5/UD_Chinese-GSDSimp/stats.xml
# ud-treebanks-v2.5/UD_Chinese-GSDSimp/zh_gsdsimp-ud-dev.conllu
# ud-treebanks-v2.5/UD_Chinese-GSDSimp/zh_gsdsimp-ud-train.txt
# ud-treebanks-v2.5/UD_Chinese-GSDSimp/README.md
# ud-treebanks-v2.5/UD_Chinese-GSDSimp/LICENSE.txt
# ud-treebanks-v2.5/UD_Chinese-GSDSimp/zh_gsdsimp-ud-train.conllu
# ud-treebanks-v2.5/UD_Chinese-GSDSimp/zh_gsdsimp-ud-test.txt
# ud-treebanks-v2.5/UD_Chinese-GSDSimp/zh_gsdsimp-ud-dev.txt
# ud-treebanks-v2.5/UD_Bambara-CRB/
# ud-treebanks-v2.5/UD_Bambara-CRB/README.md
# ud-treebanks-v2.5/UD_Bambara-CRB/stats.xml
# ud-treebanks-v2.5/UD_Bambara-CRB/bm_crb-ud-test.txt
# ud-treebanks-v2.5/UD_Bambara-CRB/LICENSE.txt
# ud-treebanks-v2.5/UD_Bambara-CRB/bm_crb-ud-test.conllu
# ud-treebanks-v2.5/UD_Breton-KEB/
# ud-treebanks-v2.5/UD_Breton-KEB/br_keb-ud-test.txt
# ud-treebanks-v2.5/UD_Breton-KEB/LICENSE.txt
# ud-treebanks-v2.5/UD_Breton-KEB/br_keb-ud-test.conllu
# ud-treebanks-v2.5/UD_Breton-KEB/README.md
# ud-treebanks-v2.5/UD_Breton-KEB/stats.xml
# ud-treebanks-v2.5/UD_Faroese-OFT/
# ud-treebanks-v2.5/UD_Faroese-OFT/fo_oft-ud-test.conllu
# ud-treebanks-v2.5/UD_Faroese-OFT/stats.xml
# ud-treebanks-v2.5/UD_Faroese-OFT/fo_oft-ud-test.txt
# ud-treebanks-v2.5/UD_Faroese-OFT/LICENSE.txt
# ud-treebanks-v2.5/UD_Faroese-OFT/README.md
# ud-treebanks-v2.5/UD_Estonian-EDT/
# ud-treebanks-v2.5/UD_Estonian-EDT/et_edt-ud-test.txt
# ud-treebanks-v2.5/UD_Estonian-EDT/stats.xml
# ud-treebanks-v2.5/UD_Estonian-EDT/et_edt-ud-test.conllu
# ud-treebanks-v2.5/UD_Estonian-EDT/et_edt-ud-dev.txt
# ud-treebanks-v2.5/UD_Estonian-EDT/et_edt-ud-train.conllu
# ud-treebanks-v2.5/UD_Estonian-EDT/et_edt-ud-dev.conllu
# ud-treebanks-v2.5/UD_Estonian-EDT/et_edt-ud-train.txt
# ud-treebanks-v2.5/UD_Estonian-EDT/LICENSE.txt
# ud-treebanks-v2.5/UD_Estonian-EDT/README.md
# ud-treebanks-v2.5/UD_Korean-GSD/
# ud-treebanks-v2.5/UD_Korean-GSD/ko_gsd-ud-train.conllu
# ud-treebanks-v2.5/UD_Korean-GSD/ko_gsd-ud-test.txt
# ud-treebanks-v2.5/UD_Korean-GSD/stats.xml
# ud-treebanks-v2.5/UD_Korean-GSD/README.md
# ud-treebanks-v2.5/UD_Korean-GSD/ko_gsd-ud-test.conllu
# ud-treebanks-v2.5/UD_Korean-GSD/ko_gsd-ud-dev.txt
# ud-treebanks-v2.5/UD_Korean-GSD/LICENSE.txt
# ud-treebanks-v2.5/UD_Korean-GSD/ko_gsd-ud-train.txt
# ud-treebanks-v2.5/UD_Korean-GSD/ko_gsd-ud-dev.conllu
# ud-treebanks-v2.5/UD_Korean-PUD/
# ud-treebanks-v2.5/UD_Korean-PUD/LICENSE.txt
# ud-treebanks-v2.5/UD_Korean-PUD/ko_pud-ud-test.txt
# ud-treebanks-v2.5/UD_Korean-PUD/ko_pud-ud-test.conllu
# ud-treebanks-v2.5/UD_Korean-PUD/README.md
# ud-treebanks-v2.5/UD_Korean-PUD/stats.xml
# ud-treebanks-v2.5/UD_Swedish-PUD/
# ud-treebanks-v2.5/UD_Swedish-PUD/sv_pud-ud-test.txt
# ud-treebanks-v2.5/UD_Swedish-PUD/README.md
# ud-treebanks-v2.5/UD_Swedish-PUD/LICENSE.txt
# ud-treebanks-v2.5/UD_Swedish-PUD/stats.xml
# ud-treebanks-v2.5/UD_Swedish-PUD/sv_pud-ud-test.conllu
# ud-treebanks-v2.5/UD_Hindi_English-HIENCS/
# ud-treebanks-v2.5/UD_Hindi_English-HIENCS/crawl_tweets.py
# ud-treebanks-v2.5/UD_Hindi_English-HIENCS/LICENSE.txt
# ud-treebanks-v2.5/UD_Hindi_English-HIENCS/README.md
# ud-treebanks-v2.5/UD_Hindi_English-HIENCS/qhe_hiencs-ud-dev.txt
# ud-treebanks-v2.5/UD_Hindi_English-HIENCS/qhe_hiencs-ud-test.txt
# ud-treebanks-v2.5/UD_Hindi_English-HIENCS/qhe_hiencs-ud-train.txt
# ud-treebanks-v2.5/UD_Hindi_English-HIENCS/merge/
# ud-treebanks-v2.5/UD_Hindi_English-HIENCS/merge/train-annot.json
# ud-treebanks-v2.5/UD_Hindi_English-HIENCS/merge/tweet_ids_dev.txt
# ud-treebanks-v2.5/UD_Hindi_English-HIENCS/merge/tweet_ids_test.txt
# ud-treebanks-v2.5/UD_Hindi_English-HIENCS/merge/test-annot.json
# ud-treebanks-v2.5/UD_Hindi_English-HIENCS/merge/DOMAINS
# ud-treebanks-v2.5/UD_Hindi_English-HIENCS/merge/dev-annot.json
# ud-treebanks-v2.5/UD_Hindi_English-HIENCS/merge/tweet_ids_train.txt
# ud-treebanks-v2.5/UD_Hindi_English-HIENCS/merge/EDITS
# ud-treebanks-v2.5/UD_Hindi_English-HIENCS/merge/NONBREAKING_PREFIXES
# ud-treebanks-v2.5/UD_Hindi_English-HIENCS/merge/EMOTICONS
# ud-treebanks-v2.5/UD_Hindi_English-HIENCS/qhe_hiencs-ud-test.conllu
# ud-treebanks-v2.5/UD_Hindi_English-HIENCS/stats.xml
# ud-treebanks-v2.5/UD_Hindi_English-HIENCS/qhe_hiencs-ud-train.conllu
# ud-treebanks-v2.5/UD_Hindi_English-HIENCS/qhe_hiencs-ud-dev.conllu
# ud-treebanks-v2.5/UD_German-HDT/
# ud-treebanks-v2.5/UD_German-HDT/stats.xml
# ud-treebanks-v2.5/UD_German-HDT/de_hdt-ud-dev.txt
# ud-treebanks-v2.5/UD_German-HDT/de_hdt-ud-dev.conllu
# ud-treebanks-v2.5/UD_German-HDT/de_hdt-ud-test.conllu
# ud-treebanks-v2.5/UD_German-HDT/LICENSE.txt
# ud-treebanks-v2.5/UD_German-HDT/de_hdt-ud-train.conllu
# ud-treebanks-v2.5/UD_German-HDT/README.md
# ud-treebanks-v2.5/UD_German-HDT/de_hdt-ud-train.txt
# ud-treebanks-v2.5/UD_German-HDT/de_hdt-ud-test.txt
# ud-treebanks-v2.5/UD_Swedish-LinES/
# ud-treebanks-v2.5/UD_Swedish-LinES/sv_lines-ud-dev.conllu
# ud-treebanks-v2.5/UD_Swedish-LinES/sv_lines-ud-train.conllu
# ud-treebanks-v2.5/UD_Swedish-LinES/stats.xml
# ud-treebanks-v2.5/UD_Swedish-LinES/README.txt
# ud-treebanks-v2.5/UD_Swedish-LinES/LICENSE.txt
# ud-treebanks-v2.5/UD_Swedish-LinES/sv_lines-ud-train.txt
# ud-treebanks-v2.5/UD_Swedish-LinES/sv_lines-ud-test.txt
# ud-treebanks-v2.5/UD_Swedish-LinES/sv_lines-ud-test.conllu
# ud-treebanks-v2.5/UD_Swedish-LinES/sv_lines-ud-dev.txt
# ud-treebanks-v2.5/UD_Hindi-HDTB/
# ud-treebanks-v2.5/UD_Hindi-HDTB/hi_hdtb-ud-dev.txt
# ud-treebanks-v2.5/UD_Hindi-HDTB/hi_hdtb-ud-test.conllu
# ud-treebanks-v2.5/UD_Hindi-HDTB/hi_hdtb-ud-dev.conllu
# ud-treebanks-v2.5/UD_Hindi-HDTB/stats.xml
# ud-treebanks-v2.5/UD_Hindi-HDTB/hi_hdtb-ud-train.txt
# ud-treebanks-v2.5/UD_Hindi-HDTB/hi_hdtb-ud-test.txt
# ud-treebanks-v2.5/UD_Hindi-HDTB/README.md
# ud-treebanks-v2.5/UD_Hindi-HDTB/LICENSE.txt
# ud-treebanks-v2.5/UD_Hindi-HDTB/hi_hdtb-ud-train.conllu
# ud-treebanks-v2.5/UD_Czech-CAC/
# ud-treebanks-v2.5/UD_Czech-CAC/cs_cac-ud-dev.txt
# ud-treebanks-v2.5/UD_Czech-CAC/LICENSE.txt
# ud-treebanks-v2.5/UD_Czech-CAC/README.md
# ud-treebanks-v2.5/UD_Czech-CAC/stats.xml
# ud-treebanks-v2.5/UD_Czech-CAC/cs_cac-ud-train.conllu
# ud-treebanks-v2.5/UD_Czech-CAC/cs_cac-ud-dev.conllu
# ud-treebanks-v2.5/UD_Czech-CAC/cs_cac-ud-test.conllu
# ud-treebanks-v2.5/UD_Czech-CAC/cs_cac-ud-test.txt
# ud-treebanks-v2.5/UD_Czech-CAC/cs_cac-ud-train.txt
# ud-treebanks-v2.5/UD_Romanian-SiMoNERo/
# ud-treebanks-v2.5/UD_Romanian-SiMoNERo/stats.xml
# ud-treebanks-v2.5/UD_Romanian-SiMoNERo/ro_simonero-ud-test.txt
# ud-treebanks-v2.5/UD_Romanian-SiMoNERo/LICENSE.txt
# ud-treebanks-v2.5/UD_Romanian-SiMoNERo/README.md
# ud-treebanks-v2.5/UD_Romanian-SiMoNERo/ro_simonero-ud-test.conllu

# %%
from io import open
from conllu import parse_incr

# %%
#Open the file and load the sentences to a list.
data_file = open("ud-treebanks-v2.5/UD_English-GUM/en_gum-ud-train.conllu", "r", encoding="utf-8")

ud_files = []
for tokenlist in parse_incr(data_file):
  ud_files.append(tokenlist)

print(f"Total number of token files :- {len(ud_files)}")
print(f"One example from the dataset :- \n {ud_files[9]}")
# Out:
# Total number of token files :- 3753
# One example from the dataset :-
#  TokenList<The, viewing, experience, of, art, is, a, complex, one, ,, involving, issues, of, perception, ,, attention, ,, memory, ,, decision-making, ,, affect, ,, and, emotion, .>

# %%
## creating tokens and corresponding tags 
ud_treebank = []
for sentence in ud_files:
  tokens = []
  tags = []
  for token in sentence:
    tokens.append(token['form'])
    tags.append(token['upostag'])
  ud_treebank.append((tokens, tags))

# %%
print(f"First Sentence & associated tags")
print(f"Sentence :- \n {ud_treebank[0][0]}")
print(f"Tags :- \n {ud_treebank[0][1]}")
# Out:
# First Sentence & associated tags
# Sentence :-
#  ['Aesthetic', 'Appreciation', 'and', 'Spanish', 'Art', ':']
# Tags :-
#  ['ADJ', 'NOUN', 'CCONJ', 'ADJ', 'NOUN', 'PUNCT']

# %%
## split whole dataset into train and test datasets
train_dataset_size = int(0.8*len(ud_treebank)) ## taken 80% of data as traning dataset
ud_treebank_training_dataset = ud_treebank[:train_dataset_size]
ud_treebank_testing_dataset = ud_treebank[train_dataset_size:]

print(f"Size of Penn treebank training dataset :- {len(ud_treebank_training_dataset)}")
print(f"Size of Penn treebank testing dataset :- {len(ud_treebank_testing_dataset)}")
# Out:
# Size of Penn treebank training dataset :- 3002
# Size of Penn treebank testing dataset :- 751

# %%
import re

# %%
## extract features from every word in the sentence
def extract_word_features(sentence, index):
  return {
      'word':sentence[index],
      'is_first':index==0,
      'is_last':index ==len(sentence)-1,
      'is_capitalized':sentence[index][0].upper() == sentence[index][0],
      'is_all_caps': sentence[index].upper() == sentence[index],
      'is_all_lower': sentence[index].lower() == sentence[index],
      'is_alphanumeric': int(bool((re.match('^(?=.*[0-9]$)(?=.*[a-zA-Z])',sentence[index])))),
      'prefix-1':sentence[index][0],
      'prefix-2':sentence[index][:2],
      'prefix-3':sentence[index][:3],
      'prefix-3':sentence[index][:4],
      'suffix-1':sentence[index][-1],
      'suffix-2':sentence[index][-2:],
      'suffix-3':sentence[index][-3:],
      'suffix-3':sentence[index][-4:],
      'prev_word':'' if index == 0 else sentence[index-1],
      'next_word':'' if index < len(sentence) else sentence[index+1],
      'has_hyphen': '-' in sentence[index],
      'is_numeric': sentence[index].isdigit(),
      'capitals_inside': sentence[index][1:].lower() != sentence[index][1:]
      }

# %%
## creating dataset from raw dataset with all word features
def transform_rawdata_dataset_format(tagged_sentences):
  X,y = [],[]
  for sentence, tags in tagged_sentences:
    sent_word_features, sent_tags = [], []
    for index in range(len(sentence)):
      sent_word_features.append(extract_word_features(sentence=sentence, index=index))
      sent_tags.append(tags[index])
    X.append(sent_word_features)
    y.append(sent_tags)
  return X,y

# %%
## create train, test datasets of features and target variables
X_ud_train, y_ud_train = transform_rawdata_dataset_format(ud_treebank_training_dataset)
X_ud_test, y_ud_test = transform_rawdata_dataset_format(ud_treebank_testing_dataset)

# %%
# !pip install sklearn_crfsuite
# Out:
# Collecting sklearn_crfsuite
#   Downloading https://files.pythonhosted.org/packages/25/74/5b7befa513482e6dee1f3dd68171a6c9dfc14c0eaa00f885ffeba54fe9b0/sklearn_crfsuite-0.3.6-py2.py3-none-any.whl
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (4.41.1)
# Collecting python-crfsuite>=0.8.3
#   Downloading https://files.pythonhosted.org/packages/95/99/869dde6dbf3e0d07a013c8eebfb0a3d30776334e0097f8432b631a9a3a19/python_crfsuite-0.9.7-cp36-cp36m-manylinux1_x86_64.whl (743kB)
#      |████████████████████████████████| 747kB 5.2MB/s
# Requirement already satisfied: tabulate in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (0.8.7)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (1.15.0)
# Installing collected packages: python-crfsuite, sklearn-crfsuite
# Successfully installed python-crfsuite-0.9.7 sklearn-crfsuite-0.3.6

# %%
import warnings 
warnings.filterwarnings('ignore')
from sklearn_crfsuite import CRF
from sklearn_crfsuite import metrics, scorers

# %%
## initialize CRF model
ud_treebank_crf = CRF(algorithm='lbfgs',
                        c1=0.01,
                        c2=0.1,
                        max_iterations= 100,
                        all_possible_transitions = True)

# %%
## training a model
print("Starting CRF model traing on Penn Treebank dataset ")
ud_treebank_crf.fit(X_ud_train, y_ud_train)
print("Completed CRF model traning on Penn Treebank Dataset sucessfully")
# Out:
# Starting CRF model traing on Penn Treebank dataset
# Completed CRF model traning on Penn Treebank Dataset sucessfully

# %%
## evaluate CRF model on test dataset
y_ud_predict_test_results =  ud_treebank_crf.predict(X_ud_test)
print("F1-score on test dataset ")
f1_score_testdata = metrics.flat_f1_score(y_ud_test, y_ud_predict_test_results, average='weighted', labels=ud_treebank_crf.classes_)
print(f1_score_testdata)

## evaluate CRF model on training dataset
y_ud_predict_train_results =  ud_treebank_crf.predict(X_ud_train)
print("F1-score on train dataset ")
f1_score_testdata = metrics.flat_f1_score(y_ud_train, y_ud_predict_train_results, average='weighted', labels=ud_treebank_crf.classes_)
print(f1_score_testdata)
# Out:
# F1-score on test dataset
# 0.9042422401050215
# F1-score on train dataset
# 0.9889075355782778

# %%
## classification report
print("Class wise score:")
print(metrics.flat_classification_report(
    y_ud_test, y_ud_predict_test_results, labels=ud_treebank_crf.classes_, digits=3
))
# Out:
# Class wise score:
#               precision    recall  f1-score   support
#
#          ADJ      0.823     0.782     0.802       864
#         NOUN      0.878     0.898     0.888      2338
#        CCONJ      0.988     0.991     0.989       425
#        PUNCT      0.998     0.992     0.995      1552
#          ADP      0.907     0.932     0.919      1090
#        PROPN      0.370     0.944     0.531       144
#        SCONJ      0.841     0.782     0.810       385
#          AUX      0.959     0.963     0.961       675
#         VERB      0.910     0.786     0.843      1689
#          DET      0.979     0.983     0.981       996
#         PRON      0.970     0.965     0.967       990
#          NUM      0.909     0.974     0.940       154
#          ADV      0.826     0.880     0.852       560
#            X      1.000     0.067     0.125        45
#          SYM      0.545     0.600     0.571        10
#         PART      0.943     0.929     0.936       408
#         INTJ      0.800     0.500     0.615         8
#
#     accuracy                          0.903     12333
#    macro avg      0.861     0.822     0.808     12333
# weighted avg      0.913     0.903     0.904     12333

# %% [markdown]
# Alphabetical listing
#
#
# ADJ: adjective
#
# 1.   ADP: adposition
# 2. ADV: adverb
# 3. AUX: auxiliary
# 4. CCONJ: coordinating conjunction
# 5. DET: determiner
# 6. INTJ: interjection
# 7. NOUN: noun
# 8. NUM: numeral
# 9. PART: particle
# 10. PRON: pronoun
# 11. PROPN: proper noun
# 12. PUNCT: punctuation
# 13. SCONJ: subordinating conjunction
# 14. SYM: symbol
# 15. VERB: verb
# 16. X: other

# %%
## apply trained model on new text data
example_sentence = "The tagger produced good results"
word_features = [extract_word_features(example_sentence.split(), index) for index in range(len(example_sentence.split()))]
results = ud_treebank_crf.predict_single(word_features)
ud_tups = [(example_sentence.split()[index], results[index]) for index in range(len(example_sentence.split()))]
print(ud_tups)
# Out:
# [('The', 'DET'), ('tagger', 'NOUN'), ('produced', 'VERB'), ('good', 'ADJ'), ('results', 'NOUN')]
